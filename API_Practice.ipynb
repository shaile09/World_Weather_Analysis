# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Create a practice set of random latitude and longitude combinations.
x = [25.12903645, 25.92017388, 26.62509167, -59.98969384, 37.30571269]
y = [-67.59741259, 11.09532135, 74.84233102, -76.89176677, -61.13376282]
coordinates = zip(x, y)

# %%
# Use the tuple() function to display the latitude and longitude combinations.
for coordinate in coordinates:
    print(coordinate[0], coordinate[1])
# Out:
# 25.12903645 -67.59741259
# 25.92017388 11.09532135
# 26.62509167 74.84233102
# -59.98969384 -76.89176677
# 37.30571269 -61.13376282

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# %%
# Use the tuple() function to display the latitude and longitude combinations.
for coordinate in coordinates:
    print(citipy.nearest_city(coordinate[0], coordinate[1]).city_name,
          citipy.nearest_city(coordinate[0], coordinate[1]).country_code)
# Out:
# kununurra au
# ryotsu jp
# daru pg
# rikitea pf
# krasnyy chikoy ru
# east london za
# saskylakh ru
# east london za
# kutahya tr
# tonk in
# boli cn
# east london za
# naftah tn
# sao filipe cv
# belushya guba ru
# achisay kz
# bethel us
# hlobyne ua
# dikson ru
# sabang id
# clyde river ca
# olga ru
# cape town za
# dingle ie
# rikitea pf
# alice springs au
# punta arenas cl
# atuona pf
# mahebourg mu
# fortuna us
# vaini to
# kodiak us
# mataura pf
# port hueneme us
# bathsheba bb
# avarua ck
# dikson ru
# grand river south east mu
# avarua ck
# rikitea pf
# bilibino ru
# san cristobal ec
# rikitea pf
# torbay ca
# east london za
# rikitea pf
# taolanaro mg
# severo-kurilsk ru
# mar del plata ar
# lerwick gb
# sao filipe cv
# sao filipe cv
# vila vu
# mar del plata ar
# chumikan ru
# atuona pf
# rikitea pf
# tuatapere nz
# concarneau fr
# san luis mx
# pevek ru
# egvekinot ru
# kapaa us
# anar darreh af
# jacksonville us
# acarau br
# mahebourg mu
# cabo san lucas mx
# ushuaia ar
# ushuaia ar
# mar del plata ar
# saskylakh ru
# port hawkesbury ca
# sola vu
# bredasdorp za
# vaini to
# rikitea pf
# daru pg
# carnarvon au
# lillooet ca
# bethel us
# pallasovka ru
# nome us
# peace river ca
# port hardy ca
# ushuaia ar
# rudnichnyy ru
# muncar id
# ozernovskiy ru
# mehamn no
# provideniya ru
# norman wells ca
# hithadhoo mv
# carnarvon au
# illoqqortoormiut gl
# luderitz na
# ushuaia ar
# mayma ru
# barrow us
# dikson ru
# komsomolskiy ru
# jamestown sh
# jerome us
# vaitupu wf
# zelenogorsk ru
# punta arenas cl
# general roca ar
# kruisfontein za
# ribeira grande pt
# buin pg
# bassano ca
# vestmannaeyjar is
# mishan cn
# constitucion mx
# rikitea pf
# ouallam ne
# busselton au
# avarua ck
# kashiwazaki jp
# vaini to
# fevralsk ru
# rikitea pf
# dikson ru
# kamenka ru
# santa maria da vitoria br
# atuona pf
# albany au
# marfino ru
# grenada us
# busselton au
# alice springs au
# deputatskiy ru
# severo-kurilsk ru
# albany au
# butaritari ki
# hervey bay au
# albany au
# lekoni ga
# victoria sc
# biltine td
# aasiaat gl
# rikitea pf
# ushuaia ar
# attawapiskat ca
# bluff nz
# senanga zm
# flinders au
# jamestown sh
# provideniya ru
# illoqqortoormiut gl
# ushuaia ar
# mpika zm
# taolanaro mg
# sioux lookout ca
# srednekolymsk ru
# dingle ie
# dubrovytsya ua
# cape town za
# dudinka ru
# zambezi zm
# torbay ca
# severouralsk ru
# mataura pf
# barentsburg sj
# clyde river ca
# upernavik gl
# thompson ca
# ust-kuyga ru
# illoqqortoormiut gl
# nantucket us
# papar my
# nyaunglebin mm
# cabo san lucas mx
# rikitea pf
# waipawa nz
# bluff nz
# parati br
# vao nc
# hermanus za
# wangaratta au
# torbay ca
# grand gaube mu
# taolanaro mg
# bluff nz
# saskylakh ru
# atuona pf
# hilo us
# illoqqortoormiut gl
# rocha uy
# bluff nz
# mogadishu so
# te anau nz
# ambilobe mg
# mehamn no
# hilo us
# vaini to
# matara lk
# rikitea pf
# taolanaro mg
# belushya guba ru
# tocopilla cl
# los llanos de aridane es
# karratha au
# thompson ca
# busselton au
# rikitea pf
# rikitea pf
# yellowknife ca
# mehamn no
# airai pw
# bolgar ru
# rikitea pf
# severo-kurilsk ru
# port alfred za
# zhob pk
# hermanus za
# puerto ayora ec
# rikitea pf
# laguna br
# rikitea pf
# mataura pf
# kenai us
# anqing cn
# chuy uy
# hermanus za
# longyearbyen sj
# srednekolymsk ru
# albany au
# fujin cn
# ushuaia ar
# faanui pf
# santiago del estero ar
# carnarvon au
# opuwo na
# ribeira grande pt
# bindura zw
# punta arenas cl
# ribeira grande pt
# mataura pf
# torbay ca
# srednekolymsk ru
# bulanash ru
# amderma ru
# coquimbo cl
# rikitea pf
# tuatapere nz
# radovljica si
# cabo san lucas mx
# hermanus za
# poum nc
# puerto ayora ec
# salgado br
# narsaq gl
# codrington ag
# punta arenas cl
# albany au
# bengkulu id
# busselton au
# new norfolk au
# simao cn
# upernavik gl
# atuona pf
# ushuaia ar
# punta arenas cl
# rikitea pf
# oranjemund na
# lucea jm
# punta arenas cl
# vaini to
# miraflores co
# hermanus za
# klaksvik fo
# sitka us
# cape town za
# puerto ayora ec
# mana gf
# guerrero negro mx
# taolanaro mg
# bengkulu id
# mar del plata ar
# coari br
# espanola us
# kapaa us
# bluff nz
# ancud cl
# tuy hoa vn
# busselton au
# mataura pf
# attawapiskat ca
# albany au
# barentsburg sj
# casambalangan ph
# paamiut gl
# lakselv no
# dikson ru
# arraial do cabo br
# cherskiy ru
# vaini to
# bilibino ru
# progreso mx
# vaini to
# yanam in
# namibe ao
# bethel us
# kapaa us
# phrai bung th
# warqla dz
# itoman jp
# katsuura jp
# albany au
# necochea ar
# illoqqortoormiut gl
# kargasok ru
# punta arenas cl
# mecca sa
# albany au
# thompson ca
# ulladulla au
# cozumel mx
# saint-philippe re
# mataura pf
# kahului us
# rikitea pf
# chokurdakh ru
# ushuaia ar
# ponta do sol cv
# lagoa pt
# saskylakh ru
# saldanha za
# barrow us
# lebu cl
# cape town za
# matara lk
# kapaa us
# mount gambier au
# ushuaia ar
# baltiysk ru
# panguna pg
# neyshabur ir
# talnakh ru
# alofi nu
# bambous virieux mu
# albany au
# qaanaaq gl
# burns lake ca
# umzimvubu za
# menomonie us
# jarjis tn
# bekhtery ua
# castro cl
# nemuro jp
# praia cv
# ushuaia ar
# mataura pf
# ancud cl
# qaanaaq gl
# haines junction ca
# kapaa us
# zambezi zm
# pierre us
# illoqqortoormiut gl
# taolanaro mg
# busselton au
# tumannyy ru
# san ramon bo
# sioux lookout ca
# vaini to
# east london za
# illoqqortoormiut gl
# illoqqortoormiut gl
# bethel us
# rungata ki
# upernavik gl
# sioux lookout ca
# harper lr
# hermanus za
# mataura pf
# sobolevo ru
# clyde river ca
# touros br
# ushuaia ar
# dicabisagan ph
# cape town za
# talnakh ru
# puerto ayora ec
# saint-philippe re
# cape town za
# norman wells ca
# puerto ayora ec
# zinder ne
# bengkulu id
# ribeira grande pt
# saldanha za
# tuktoyaktuk ca
# avarua ck
# nizhneyansk ru
# ponta do sol cv
# carnarvon au
# busselton au
# busselton au
# illoqqortoormiut gl
# tuktoyaktuk ca
# sofiyivka ua
# codrington ag
# vaitupu wf
# atuona pf
# mataura pf
# isangel vu
# carnarvon au
# dovolnoye ru
# ganzhou cn
# sao joao da barra br
# lorengau pg
# upernavik gl
# cabo san lucas mx
# mataura pf
# bredasdorp za
# adrar dz
# cape town za
# nouadhibou mr
# port hawkesbury ca
# nanortalik gl
# yacuiba bo
# hilo us
# tuktoyaktuk ca
# saldanha za
# port alfred za
# bethel us
# kapaa us
# yulara au
# dikson ru
# rawah iq
# kapaa us
# bredasdorp za
# cape town za
# saskylakh ru
# san rafael bo
# suntar ru
# hobart au
# sahrak af
# punta arenas cl
# kapaa us
# jinchengjiang cn
# ayios matthaios gr
# punta arenas cl
# bredasdorp za
# vaini to
# kangaatsiaq gl
# leningradskiy ru
# taolanaro mg
# bathsheba bb
# rylsk ru
# litovko ru
# punta arenas cl
# grand centre ca
# liancheng cn
# erdenet mn
# coquimbo cl
# carnarvon au
# tucuma br
# dikson ru
# stantsiya gorchakovo uz
# bethel us
# rikitea pf
# karratha au
# santa isabel mx
# vaini to
# upernavik gl
# camacha pt
# vallenar cl
# busselton au
# stokmarknes no
# ponta do sol cv
# bethel us
# jamestown sh
# haines junction ca
# awjilah ly
# leshan cn
# hermanus za
# taolanaro mg
# tezu in
# tsihombe mg
# yellowknife ca
# louisbourg ca
# cardston ca
# sambava mg
# athabasca ca
# college us
# leningradskiy ru
# hithadhoo mv
# severo-kurilsk ru
# sassandra ci
# hobart au
# port hedland au
# nanakuli us
# busselton au
# sayyan ye
# ribeira grande pt
# labutta mm
# lucapa ao
# broome au
# tuktoyaktuk ca
# sardarpur in
# arraial do cabo br
# sentyabrskiy ru
# rikitea pf
# atuona pf
# floresti md
# nizhneyansk ru
# georgetown sh
# castro cl
# bluff nz
# ribeira grande pt
# mantua cu
# bethel us
# illoqqortoormiut gl
# hithadhoo mv
# grand river south east mu
# barrow us
# grindavik is
# nantucket us
# sentyabrskiy ru
# busselton au
# hermanus za
# torbay ca
# ribeira grande pt
# rikitea pf
# bengkulu id
# albany au
# lasa cn
# ballina ie
# portland au
# bluff nz
# vaini to
# kaitong cn
# barrow us
# kieta pg
# mataura pf
# maningrida au
# barcelos br
# puerto ayora ec
# khani ru
# alofi nu
# camana pe
# busselton au
# jamestown sh
# dudinka ru
# new norfolk au
# katherine au
# luderitz na
# chitrakonda in
# avarua ck
# saskylakh ru
# vaini to
# zhigansk ru
# esperance au
# huazolotitlan mx
# rikitea pf
# bengkulu id
# yellowknife ca
# lebu cl
# dicabisagan ph
# acari pe
# mataura pf
# airai pw
# kirovskiy ru
# rikitea pf
# lebu cl
# punta arenas cl
# mar del plata ar
# bandarbeyla so
# ushuaia ar
# mahebourg mu
# coahuayana mx
# bluff nz
# bambous virieux mu
# vaini to
# salinas ec
# castro cl
# hermanus za
# sioux lookout ca
# ji-parana br
# butaritari ki
# chokurdakh ru
# severo-kurilsk ru
# saint-philippe re
# guerrero negro mx
# provideniya ru
# cape town za
# dikson ru
# albany au
# college us
# tailai cn
# illoqqortoormiut gl
# aksu cn
# new norfolk au
# east london za
# kaitangata nz
# tawkar sd
# albany au
# faanui pf
# torbay ca
# longyearbyen sj
# qaanaaq gl
# barrow us
# kamenskoye ru
# saint-philippe re
# kaitangata nz
# souillac mu
# hermanus za
# port alfred za
# kavaratti in
# sitka us
# cape town za
# new norfolk au
# alamogordo us
# hasaki jp
# port alfred za
# coihaique cl
# saldanha za
# doha kw
# caravelas br
# kodiak us
# hilo us
# thompson ca
# rikitea pf
# kondinskoye ru
# san carlos de bariloche ar
# glenwood springs us
# bambous virieux mu
# itarema br
# sinnamary gf
# torbay ca
# geraldton ca
# zhigansk ru
# punta arenas cl
# eureka us
# attawapiskat ca
# cape town za
# thompson ca
# kitimat ca
# busselton au
# saint george bm
# lebu cl
# ushuaia ar
# upernavik gl
# thompson ca
# bluff nz
# havoysund no
# isiro cd
# west bay ky
# sorland no
# albany au
# vanimo pg
# taoudenni ml
# vaini to
# karauzyak uz
# mataura pf
# illoqqortoormiut gl
# busselton au
# avarua ck
# kysyl-syr ru
# dikson ru
# khatanga ru
# vaini to
# bethel us
# rocha uy
# tasiilaq gl
# busselton au
# saleaula ws
# roald no
# hsinying tw
# ushuaia ar
# butaritari ki
# saint-philippe re
# sao filipe cv
# riyadh sa
# nouadhibou mr
# te anau nz
# formoso do araguaia br
# georgetown sh
# atuona pf
# kirakira sb
# thompson ca
# plouzane fr
# taolanaro mg
# albany au
# puerto ayora ec
# albany au
# pokhara np
# ilulissat gl
# faanui pf
# rikitea pf
# albany au
# hobart au
# bosobolo cd
# onufriyivka ua
# yefremov ru
# ushuaia ar
# luderitz na
# lorengau pg
# taolanaro mg
# vaini to
# rikitea pf
# avarua ck
# hendek tr
# rikitea pf
# mihijam in
# hobart au
# lakhimpur in
# albany au
# tarcea ro
# teya ru
# louisbourg ca
# rikitea pf
# chimore bo
# fujieda jp
# peniche pt
# mataura pf
# punta arenas cl
# kavaratti in
# east london za
# spilimbergo it
# hobart au
# kodiak us
# barpeta in
# fuling cn
# hermanus za
# ushuaia ar
# busselton au
# iqaluit ca
# amderma ru
# cherskiy ru
# deputatskiy ru
# puerto ayora ec
# puerto ayora ec
# amderma ru
# albany au
# new norfolk au
# tarakan id
# rikitea pf
# mataura pf
# punta arenas cl
# jamestown sh
# tumalaytay ph
# sentyabrskiy ru
# charters towers au
# ushuaia ar
# paamiut gl
# tasiilaq gl
# mustafakemalpasa tr
# progreso mx
# punta arenas cl
# hermanus za
# narsaq gl
# amderma ru
# bengkulu id
# new norfolk au
# jamestown sh
# cherskiy ru
# qaanaaq gl
# punta arenas cl
# jamestown sh
# sao filipe cv
# mount gambier au
# sistranda no
# pafos cy
# yellowknife ca
# thompson ca
# busselton au
# berlevag no
# tiksi ru
# tasiilaq gl
# punta arenas cl
# vila velha br
# thompson ca
# broken hill au
# moron mn
# atuona pf
# stornoway gb
# airai pw
# thompson ca
# lilongwe mw
# sentyabrskiy ru
# rikitea pf
# ixtapa mx
# alugan ph
# busselton au
# caravelas br
# kaitangata nz
# yellowknife ca
# hermanus za
# kodiak us
# avarua ck
# havre-saint-pierre ca
# busselton au
# pevek ru
# norman wells ca
# isangel vu
# russell nz
# portland au
# buchanan lr
# iqaluit ca
# mataura pf
# amderma ru
# antibes fr
# besikduzu tr
# albany au
# roebourne au
# tumannyy ru
# alekseyevsk ru
# arraial do cabo br
# hermanus za
# mar del plata ar
# carnarvon au
# kaitangata nz
# rikitea pf
# thompson ca
# caravelas br
# verkhnevilyuysk ru
# blenheim ca
# port alfred za
# vestmanna fo
# punta arenas cl
# ushuaia ar
# ushuaia ar
# hobart au
# albany au
# loiza us
# rikitea pf
# kaitangata nz
# rikitea pf
# qaanaaq gl
# san cristobal ec
# taolanaro mg
# busselton au
# cherskiy ru
# castro cl
# castro cl
# ushuaia ar
# aldan ru
# faanui pf
# kodiak us
# bandarbeyla so
# oistins bb
# caranavi bo
# ushuaia ar
# sao jose da coroa grande br
# naze jp
# amaga ph
# mahebourg mu
# ushuaia ar
# lavrentiya ru
# puerto ayora ec
# christchurch nz
# port elizabeth za
# vestmannaeyjar is
# punta arenas cl
# husavik is
# la orilla mx
# makakilo city us
# bluff nz
# fairbanks us
# kadykchan ru
# srednekolymsk ru
# tasiilaq gl
# mahebourg mu
# inta ru
# saint george bm
# ushuaia ar
# jamestown sh
# boende cd
# nome us
# tazovskiy ru
# ankazobe mg
# neiafu to
# punta arenas cl
# carnarvon au
# atuona pf
# hermanus za
# rikitea pf
# rikitea pf
# severo-kurilsk ru
# namibe ao
# carauari br
# montana bg
# hithadhoo mv
# new norfolk au
# arraial do cabo br
# butaritari ki
# olafsvik is
# grand river south east mu
# santa isabel mx
# victor harbor au
# katsuura jp
# chokurdakh ru
# barrow us
# tuktoyaktuk ca
# port hardy ca
# praia da vitoria pt
# severo-kurilsk ru
# punta arenas cl
# hambantota lk
# barentsburg sj
# barrow us
# nikolskoye ru
# castro cl
# ponta do sol cv
# ternate id
# madimba tz
# khatanga ru
# paamiut gl
# bluff nz
# baghdad iq
# lebu cl
# albany au
# east london za
# gamba ga
# pevek ru
# longyearbyen sj
# santa marta co
# dukat ru
# carnarvon au
# georgetown sh
# atuona pf
# port hardy ca
# west odessa us
# saint-philippe re
# kapaa us
# port alfred za
# ushuaia ar
# kapaa us
# mataura pf
# itaituba br
# rikitea pf
# jamestown sh
# hilo us
# atuona pf
# rosamorada mx
# leh in
# bilma ne
# ekhabi ru
# dalvik is
# port elizabeth za
# souillac mu
# kaitangata nz
# atuona pf
# elizabeth city us
# pangnirtung ca
# souillac mu
# lebu cl
# tuktoyaktuk ca
# ushuaia ar
# rikitea pf
# esperance au
# ucluelet ca
# villa bruzual ve
# atuona pf
# grand gaube mu
# rikitea pf
# butaritari ki
# omboue ga
# yellowknife ca
# amderma ru
# flinders au
# tiksi ru
# turbat pk
# ushuaia ar
# ushuaia ar
# hermanus za
# saskylakh ru
# rikitea pf
# mataura pf
# hilo us
# mataura pf
# vyazemskiy ru
# nakusp ca
# carnarvon au
# port hardy ca
# mys shmidta ru
# mys shmidta ru
# bilma ne
# luderitz na
# tuktoyaktuk ca
# yeppoon au
# hermanus za
# bethel us
# kodinar in
# cerritos mx
# llallagua bo
# belaya gora ru
# qaanaaq gl
# suratgarh in
# luderitz na
# banjar id
# east london za
# nemuro jp
# sentyabrskiy ru
# mar del plata ar
# puerto del rosario es
# bambous virieux mu
# lebu cl
# albany au
# tuktoyaktuk ca
# rikitea pf
# ushuaia ar
# yumen cn
# opobo ng
# sao joao da barra br
# meulaboh id
# albany au
# saint johnsbury us
# mahebourg mu
# cabo san lucas mx
# hilo us
# ushuaia ar
# saint-raphael fr
# arraial do cabo br
# kaka tm
# busselton au
# mataura pf
# ponta do sol cv
# arraial do cabo br
# taolanaro mg
# quang ngai vn
# vaini to
# amderma ru
# hilo us
# longyearbyen sj
# bluff nz
# saint stephen ca
# victoria sc
# mahebourg mu
# zmeinogorsk ru
# djambala cg
# mys shmidta ru
# albany au
# manacor es
# vila velha br
# anadyr ru
# mataura pf
# aluksne lv
# bud no
# fortuna us
# busselton au
# asau tv
# busselton au
# illoqqortoormiut gl
# mys shmidta ru
# erzin ru
# hermanus za
# rikitea pf
# beyneu kz
# busselton au
# ushuaia ar
# toliary mg
# rusne lt
# hermanus za
# saskylakh ru
# butaritari ki
# port alfred za
# gat ly
# kodiak us
# nizhneyansk ru
# marcona pe
# avera pf
# san patricio mx
# rikitea pf
# werda bw
# nikolskoye ru
# faanui pf
# oranjemund na
# ribeira grande pt
# jamestown sh
# goderich sl
# saint-philippe re
# tiksi ru
# vila velha br
# cherskiy ru
# gazojak tm
# sarangani ph
# yamada jp
# talara pe
# itarema br
# cayenne gf
# vaitupu wf
# hithadhoo mv
# nanortalik gl
# souillac mu
# bonavista ca
# magadan ru
# luderitz na
# tiksi ru
# ancud cl
# kununurra au
# arraial do cabo br
# bluff nz
# rostaq af
# labuhan id
# hithadhoo mv
# mana gf
# mataura pf
# kodiak us
# kon tum vn
# kitimat ca
# kashi cn
# biak id
# yellowknife ca
# rikitea pf
# belushya guba ru
# ohara jp
# albany au
# port elizabeth za
# shingu jp
# hobart au
# punta arenas cl
# mount gambier au
# port alfred za
# bredasdorp za
# verkh-chebula ru
# portland au
# bijbiara in
# nyagan ru
# auki sb
# zyryanka ru
# rikitea pf
# pingliang cn
# avera pf
# belushya guba ru
# vila franca do campo pt
# abashiri jp
# bluff nz
# zonguldak tr
# fort saint john ca
# mataura pf
# illoqqortoormiut gl
# kavieng pg
# victoria sc
# pizarro co
# hobart au
# khatanga ru
# ajdabiya ly
# qaanaaq gl
# acarau br
# mataura pf
# albany au
# illoqqortoormiut gl
# east london za
# tabiauea ki
# ushuaia ar
# touros br
# namibe ao
# araguacu br
# bathsheba bb
# saint-augustin ca
# clyde river ca
# ust-maya ru
# ahipara nz
# new norfolk au
# ushuaia ar
# yima cn
# hermanus za
# bengkulu id
# mataura pf
# mar del plata ar
# agadir ma
# mataura pf
# sitka us
# jamestown sh
# punta arenas cl
# illoqqortoormiut gl
# butaritari ki
# barrow us
# tuatapere nz
# broome au
# avarua ck
# sibolga id
# chuy uy
# isangel vu
# ushuaia ar
# cape town za
# kavieng pg
# upernavik gl
# port alfred za
# kloulklubed pw
# airai pw
# deputatskiy ru
# olinda br
# bluff nz
# nizhneyansk ru
# airai pw
# severo-kurilsk ru
# venado tuerto ar
# isangel vu
# hopewell us
# ushuaia ar
# chokurdakh ru
# vrangel ru
# cape town za
# passagem franca br
# vaini to
# hermanus za
# ushuaia ar
# fare pf
# healesville au
# iquique cl
# belushya guba ru
# coahuayana mx
# hermanus za
# santana br
# nelson bay au
# chuy uy
# tautira pf
# kaitangata nz
# tretten no
# chokurdakh ru
# sorong id
# tuatapere nz
# ushuaia ar
# new norfolk au
# nikolskoye ru
# nemuro jp
# tasiilaq gl
# bethel us
# norman wells ca
# port alfred za
# vaitupu wf
# mercedes ar
# punta arenas cl
# suhl de
# hilo us
# tasiilaq gl
# busselton au
# angoche mz
# port alfred za
# albany au
# mataura pf
# madhipura in
# kapaa us
# khatanga ru
# new norfolk au
# katsuura jp
# meyungs pw
# hokitika nz
# rikitea pf
# khatanga ru
# hermanus za
# tombouctou ml
# ajdabiya ly
# ranfurly nz
# kruisfontein za
# tuatapere nz
# tasiilaq gl
# domoni km
# beringovskiy ru
# lompoc us
# dwarka in
# taolanaro mg
# hobart au
# port alfred za
# hovd mn
# mahebourg mu
# aksu cn
# ushuaia ar
# bredasdorp za
# busselton au
# mys shmidta ru
# parabel ru
# nyurba ru
# atuona pf
# wulanhaote cn
# albany au
# butaritari ki
# rikitea pf
# yellowknife ca
# port alfred za
# sarmizegetusa ro
# atuona pf
# castro cl
# mocuba mz
# hofn is
# vaini to
# cabo san lucas mx
# aurad in
# rikitea pf
# new norfolk au
# linhares br
# punta arenas cl
# albany au
# saskylakh ru
# ancud cl
# grindavik is
# hasaki jp
# tuktoyaktuk ca
# san quintin mx
# codrington ag
# mataura pf
# vysokogornyy ru
# mabaruma gy
# mataura pf
# ridgecrest us
# bluff nz
# codrington ag
# port alfred za
# saskylakh ru
# cortez us
# buraydah sa
# sompeta in
# mataura pf
# longyearbyen sj
# rikitea pf
# sivas tr
# atar mr
# valparaiso cl
# burica pa
# yellowknife ca
# carnarvon au
# busselton au
# marsh harbour bs
# turukhansk ru
# saleaula ws
# besuki id
# bambous virieux mu
# vaini to
# jiangyou cn
# bismarck us
# rikitea pf
# upernavik gl
# punta arenas cl
# weligama lk
# halden no
# hamilton bm
# aklavik ca
# ushuaia ar
# avarua ck
# bolungarvik is
# bredasdorp za
# yurginskoye ru
# eyl so
# leningradskiy ru
# mataura pf
# san cristobal ec
# lantana us
# airai pw
# albany au
# barra do corda br
# huarmey pe
# ilhabela br
# samusu ws
# taolanaro mg
# lorengau pg
# barrow us
# vanimo pg
# oksfjord no
# atuona pf
# vaini to
# nguiu au
# albany au
# taolanaro mg
# sistranda no
# khatanga ru
# ushuaia ar
# bredasdorp za
# punta arenas cl
# zaraza ve
# provideniya ru
# bandar-e lengeh ir
# bluff nz
# kiunga pg
# port elizabeth za
# saint george bm
# cape town za
# padang id
# yumen cn
# constitucion mx
# saskylakh ru
# mentok id
# kaitangata nz
# richards bay za
# aklavik ca
# busselton au
# katsuura jp
# punta arenas cl
# bluff nz
# karratha au
# kodiak us
# northam au
# hualmay pe
# rikitea pf
# carnarvon au
# puerto ayora ec
# tiksi ru
# chokurdakh ru
# cherskiy ru
# barrow us
# rikitea pf
# hilo us
# lagoa pt
# belushya guba ru
# amderma ru
# castro cl
# nanortalik gl
# rikitea pf
# carutapera br
# sibolga id
# tyukhtet ru
# nanortalik gl
# aklavik ca
# tomari ru
# ayagoz kz
# phayao th
# longyearbyen sj
# albany au
# pacific grove us
# ribeira brava cv
# saldanha za
# ilulissat gl
# korla cn
# ilulissat gl
# fortuna foothills us
# asau tv
# caruray ph
# mar del plata ar
# hilo us
# san patricio mx
# ulaangom mn
# basco ph
# chuy uy
# marondera zw
# souillac mu
# quatre cocos mu
# hobart au
# san cristobal ec
# bucerias mx
# cidreira br
# illoqqortoormiut gl
# cap malheureux mu
# hobart au
# ruteng id
# maniitsoq gl
# ilulissat gl
# kapaa us
# barentsburg sj
# samarai pg
# doctor pedro p. pena py
# inongo cd
# beawar in
# bluff nz
# vaini to
# atuona pf
# mys shmidta ru
# punta arenas cl
# saldanha za
# port blair in
# khatanga ru
# saint-philippe re
# butaritari ki
# avarua ck
# ushuaia ar
# joao neiva br
# isangel vu
# tuatapere nz
# grindavik is
# verkhoyansk ru
# castro cl
# naron es
# angoche mz
# taoudenni ml
# jamestown sh
# pecos us
# fare pf
# ushuaia ar
# namwala zm
# khatanga ru
# cape town za
# taolanaro mg
# lasa cn
# new norfolk au
# faya td
# alyangula au
# kapaa us
# pisco pe
# azimur ma
# san quintin mx
# pierre us
# bargal so
# san cristobal ec
# hilo us
# wanning cn
# jamalpur bd
# ancud cl
# ushuaia ar
# kapaa us
# cape town za
# faanui pf
# itarema br
# narsaq gl
# hithadhoo mv
# flin flon ca
# rikitea pf

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 606

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8e3d09a8d15b0ab48cc80cd774ca879e

# %%
# Create an endpoint URL for a city.
city_url = url + "&q=" + "Boston"
print(city_url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8e3d09a8d15b0ab48cc80cd774ca879e&q=Boston

# %%
# Make a 'Get' request for the city weather.
city_weather = requests.get(city_url)
city_weather
# Out:
# <Response [200]>

# %%
city_weather.status_code
# Out:
# 200

# %%
# Create an endpoint URL for a city.
city_url = url + "&q=" + "Bston"
city_weather = requests.get(city_url)
city_weather
# Out:
# <Response [404]>

# %%
# Create an endpoint URL for a city.
city_url = url + "&q=" + "Boston"
city_weather = requests.get(city_url)
city_weather
# Out:
# <Response [200]>

# %%
# Get the text of the 'Get' request.
city_weather.text
# Out:
# '{"coord":{"lon":-71.06,"lat":42.36},"weather":[{"id":800,"main":"Clear","description":"clear sky","icon":"01d"}],"base":"stations","main":{"temp":39.34,"feels_like":29.61,"temp_min":35.01,"temp_max":43,"pressure":1012,"humidity":41},"visibility":16093,"wind":{"speed":8.05,"deg":250,"gust":14.99},"clouds":{"all":1},"dt":1577984103,"sys":{"type":1,"id":4210,"country":"US","sunrise":1577967208,"sunset":1578000140},"timezone":-18000,"id":4930956,"name":"Boston","cod":200}'

# %%
# Get the JSON text of the 'Get' request.
city_weather.json()
# Out:
# {'coord': {'lon': -71.06, 'lat': 42.36},
#  'weather': [{'id': 800,
#    'main': 'Clear',
#    'description': 'clear sky',
#    'icon': '01d'}],
#  'base': 'stations',
#  'main': {'temp': 39.34,
#   'feels_like': 29.61,
#   'temp_min': 35.01,
#   'temp_max': 43,
#   'pressure': 1012,
#   'humidity': 41},
#  'visibility': 16093,
#  'wind': {'speed': 8.05, 'deg': 250, 'gust': 14.99},
#  'clouds': {'all': 1},
#  'dt': 1577984103,
#  'sys': {'type': 1,
#   'id': 4210,
#   'country': 'US',
#   'sunrise': 1577967208,
#   'sunset': 1578000140},
#  'timezone': -18000,
#  'id': 4930956,
#  'name': 'Boston',
#  'cod': 200}

# %%
# Create an endpoint URL for a city.
city_url = url + "&q=" + "Boston"
city_weather = requests.get(city_url)
if city_weather.status_code == 200:
    print(f"City Weather found.")
else:
    print(f"City weather not found.")
# Out:
# City Weather found.

# %%
# Create an endpoint URL for a city.
city_url = url + "&q=" + "Bston"
city_weather = requests.get(city_url)
if city_weather.json():
    print(f"City Weather found.")
else:
    print(f"City weather not found.")
# Out:
# City Weather found.

# %%
print(city_url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8e3d09a8d15b0ab48cc80cd774ca879e&q=Boston

# %%
# Create an endpoint URL for a city.
city_url = url + "&q=" + "Boston"
city_weather = requests.get(city_url)
city_weather.json()
# Out:
# {'coord': {'lon': -71.06, 'lat': 42.36},
#  'weather': [{'id': 800,
#    'main': 'Clear',
#    'description': 'clear sky',
#    'icon': '01d'}],
#  'base': 'stations',
#  'main': {'temp': 39.34,
#   'feels_like': 29.61,
#   'temp_min': 35.01,
#   'temp_max': 43,
#   'pressure': 1012,
#   'humidity': 41},
#  'visibility': 16093,
#  'wind': {'speed': 8.05, 'deg': 250, 'gust': 14.99},
#  'clouds': {'all': 1},
#  'dt': 1577984103,
#  'sys': {'type': 1,
#   'id': 4210,
#   'country': 'US',
#   'sunrise': 1577967208,
#   'sunset': 1578000140},
#  'timezone': -18000,
#  'id': 4930956,
#  'name': 'Boston',
#  'cod': 200}

# %%
# Get the JSON data.
boston_data = city_weather.json()

# %%
boston_data['sys']
# Out:
# {'type': 1,
#  'id': 4210,
#  'country': 'US',
#  'sunrise': 1577967208,
#  'sunset': 1578000140}

# %%
boston_data["sys"]["country"]
# Out:
# 'US'

# %%
boston_data["dt"]
# Out:
# 1577984103

# %%
lat = boston_data["coord"]["lat"]
lng = boston_data["coord"]["lon"]
max_temp = boston_data["main"]["temp_max"]
humidity = boston_data["main"]["humidity"]
clouds = boston_data["clouds"]["all"]
wind = boston_data["wind"]["speed"]
print(lat, lng, max_temp, humidity, clouds, wind)
# Out:
# 42.36 -71.06 43 41 1 8.05

# %%
boston_data["dt"]
# Out:
# 1577984103

# %%
# Import the datetime module from the datetime library.
from datetime import datetime
# Get the date from the JSON file.
date = boston_data["dt"]
# Convert the UTC date to a date format with year, month, day, hours, minutes, and seconds.
datetime.utcfromtimestamp(date).strftime('%Y-%m-%d %H:%M:%S')
# Out:
# '2020-01-02 16:55:03'
