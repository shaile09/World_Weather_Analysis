# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Create a practice set of random latitude and longitude combinations.
x = [25.12903645, 25.92017388, 26.62509167, -59.98969384, 37.30571269]
y = [-67.59741259, 11.09532135, 74.84233102, -76.89176677, -61.13376282]
coordinates = zip(x, y)

# %%
# Use the tuple() function to display the latitude and longitude combinations.
for coordinate in coordinates:
    print(coordinate[0], coordinate[1])
# Out:
# 25.12903645 -67.59741259
# 25.92017388 11.09532135
# 26.62509167 74.84233102
# -59.98969384 -76.89176677
# 37.30571269 -61.13376282

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# %%
# Use the tuple() function to display the latitude and longitude combinations.
for coordinate in coordinates:
    print(citipy.nearest_city(coordinate[0], coordinate[1]).city_name,
          citipy.nearest_city(coordinate[0], coordinate[1]).country_code)
# Out:
# ribeira grande pt
# ushuaia ar
# attawapiskat ca
# victoria sc
# nizhnevartovsk ru
# jamestown sh
# asau tv
# bethel us
# illoqqortoormiut gl
# jamestown sh
# rikitea pf
# progreso mx
# punta arenas cl
# saint-philippe re
# kangaatsiaq gl
# vikulovo ru
# ushuaia ar
# busselton au
# port alfred za
# vila franca do campo pt
# saskylakh ru
# sitka us
# punta arenas cl
# vaitupu wf
# georgetown sh
# palabuhanratu id
# rikitea pf
# rikitea pf
# ribeira grande pt
# grand gaube mu
# rikitea pf
# bengkulu id
# chokurdakh ru
# falmouth us
# wanning cn
# bethel us
# mataura pf
# belushya guba ru
# hobart au
# tabiauea ki
# karamea nz
# bethel us
# rikitea pf
# khatanga ru
# hilo us
# fort smith us
# namatanai pg
# albany au
# lensk ru
# saint george bm
# quatre cocos mu
# saleaula ws
# cayenne gf
# taunsa pk
# angoche mz
# saraza ph
# cavalcante br
# rikitea pf
# vaini to
# hobyo so
# abu dhabi ae
# prince rupert ca
# punta arenas cl
# mataura pf
# albany au
# khatanga ru
# novouzensk ru
# grand river south east mu
# mys shmidta ru
# coihaique cl
# cazones mx
# castro cl
# butaritari ki
# mataura pf
# nikolskoye ru
# dingle ie
# punta arenas cl
# olinda br
# hasaki jp
# tiksi ru
# kodiak us
# green river us
# mahebourg mu
# rikitea pf
# vao nc
# husavik is
# busselton au
# requena pe
# lolua tv
# mataura pf
# nizhneyansk ru
# jamestown sh
# punta arenas cl
# barentsburg sj
# wolbrom pl
# kapaa us
# san cristobal ec
# inhambane mz
# tingi tz
# temaraia ki
# cape town za
# ushuaia ar
# airai pw
# barentsburg sj
# la ronge ca
# butaritari ki
# punta arenas cl
# qaanaaq gl
# taolanaro mg
# nipawin ca
# deputatskiy ru
# abapo bo
# adre td
# jawhar so
# kapaa us
# punta arenas cl
# hermanus za
# alofi nu
# airai pw
# grand centre ca
# ushuaia ar
# manosque fr
# clyde river ca
# katsuura jp
# basse gm
# cidreira br
# cidreira br
# newport news us
# barentsburg sj
# tuktoyaktuk ca
# santa isabel mx
# vaini to
# saint-philippe re
# shelburne ca
# teknaf bd
# fortuna us
# tura ru
# pavlodar kz
# arraial do cabo br
# punta arenas cl
# oistins bb
# albany au
# kodiak us
# tasiilaq gl
# port elizabeth za
# thohoyandou za
# pangnirtung ca
# cabo san lucas mx
# beringovskiy ru
# korhogo ci
# ishigaki jp
# bethel us
# barentsburg sj
# carnarvon au
# souillac mu
# jamestown sh
# lompoc us
# antibes fr
# romny ru
# evensk ru
# namatanai pg
# bambous virieux mu
# yurgamysh ru
# karak pk
# cordoba ar
# seoul kr
# rikitea pf
# mataura pf
# orlik ru
# porto torres it
# cabedelo br
# kupang id
# busselton au
# portland au
# kargasok ru
# cordoba ar
# mount gambier au
# new norfolk au
# bredasdorp za
# barrow us
# albany au
# ushuaia ar
# butaritari ki
# illoqqortoormiut gl
# jamestown sh
# ribeira grande pt
# cidreira br
# north platte us
# east london za
# cape town za
# powell river ca
# mar del plata ar
# port alfred za
# kapaa us
# pangnirtung ca
# lorengau pg
# flin flon ca
# ushuaia ar
# bolungarvik is
# nouadhibou mr
# barrow us
# torbay ca
# clyde river ca
# griffith au
# punta arenas cl
# zinder ne
# kajaani fi
# tripoli ly
# srednekolymsk ru
# evensk ru
# port alfred za
# ushuaia ar
# kapaa us
# ilulissat gl
# busselton au
# hobart au
# mahebourg mu
# lompoc us
# kudahuvadhoo mv
# lasa cn
# rikitea pf
# albany au
# rikitea pf
# natal br
# rikitea pf
# yellowknife ca
# bilibino ru
# taolanaro mg
# atar mr
# tuktoyaktuk ca
# ushuaia ar
# jiancheng cn
# ushuaia ar
# bayangol ru
# arraial do cabo br
# teahupoo pf
# lishui cn
# belushya guba ru
# ushuaia ar
# lebu cl
# opuwo na
# ushuaia ar
# sao pedro da aldeia br
# tsihombe mg
# hami cn
# rikitea pf
# itaituba br
# nikolskoye ru
# busselton au
# itarema br
# hermanus za
# busselton au
# ushuaia ar
# ribeira grande pt
# kalomo zm
# laguna br
# new norfolk au
# taylor us
# nanortalik gl
# egvekinot ru
# ardakan ir
# ushuaia ar
# morro bay us
# coquimbo cl
# albany au
# mataura pf
# bezhanitsy ru
# puerto ayora ec
# mataura pf
# half moon bay us
# goedereede nl
# jamestown sh
# busselton au
# laramie us
# volgodonsk ru
# lalmohan bd
# coromandel br
# khatanga ru
# port alfred za
# mataura pf
# geraldton au
# saskylakh ru
# dikson ru
# scottsburgh za
# bom sucesso br
# comodoro rivadavia ar
# napasar in
# cape town za
# isangel vu
# la ronge ca
# tiksi ru
# ushuaia ar
# dharchula in
# ushuaia ar
# sarangani ph
# kodiak us
# bluff nz
# auki sb
# fare pf
# vaitupu wf
# las palmas es
# pevek ru
# jamestown sh
# cayenne gf
# sitka us
# saint-philippe re
# harper lr
# kruisfontein za
# barentsburg sj
# nikolskoye ru
# rikitea pf
# jamestown sh
# esperance au
# marawi sd
# mataura pf
# cape town za
# dolinsk ru
# karpathos gr
# mariental na
# quatre cocos mu
# bluff nz
# nizhneyansk ru
# barrow us
# atuona pf
# arraial do cabo br
# vaini to
# puerto ayora ec
# bredasdorp za
# tuktoyaktuk ca
# mys shmidta ru
# brownsville us
# fuengirola es
# provideniya ru
# barrow us
# avarua ck
# kapaa us
# constitucion mx
# port alfred za
# atuona pf
# cidreira br
# castro cl
# rikitea pf
# camopi gf
# sentyabrskiy ru
# bilma ne
# yellowknife ca
# vestmanna fo
# charters towers au
# taolanaro mg
# vangaindrano mg
# mataura pf
# dikson ru
# carnarvon au
# botwood ca
# roald no
# machinga mw
# busselton au
# okhotsk ru
# xicotencatl mx
# east london za
# kenora ca
# butaritari ki
# mar del plata ar
# airai pw
# vila vu
# sentyabrskiy ru
# nabire id
# butaritari ki
# moiyabana bw
# srandakan id
# busselton au
# vaini to
# avarua ck
# provideniya ru
# bethel us
# hobart au
# amderma ru
# borogontsy ru
# yellowknife ca
# barrow us
# barrow us
# sur om
# rikitea pf
# tuktoyaktuk ca
# rehoboth na
# itapua poty py
# tarudant ma
# santa rosa ar
# tiksi ru
# torbay ca
# bambous virieux mu
# severodvinsk ru
# punta arenas cl
# pumiao cn
# kapaa us
# kamiiso jp
# bluff nz
# hermanus za
# illoqqortoormiut gl
# albany au
# san patricio mx
# ambilobe mg
# rikitea pf
# komsomolskiy ru
# provideniya ru
# saint-georges gf
# barrow us
# sambava mg
# vaini to
# gumdag tm
# bluff nz
# vaini to
# chokurdakh ru
# cape town za
# busselton au
# vostok ru
# chokurdakh ru
# qaanaaq gl
# yellowknife ca
# busselton au
# nantai cn
# mabaruma gy
# westport nz
# carnarvon au
# ekuvukeni za
# upernavik gl
# aden ye
# san quintin mx
# japura br
# sentyabrskiy ru
# taoudenni ml
# hilo us
# puerto ayora ec
# taolanaro mg
# tiksi ru
# thompson ca
# merauke id
# castro cl
# barrow us
# atuona pf
# ushuaia ar
# barinas ve
# ancud cl
# hovd mn
# rikitea pf
# castro cl
# chaa-khol ru
# mataura pf
# illoqqortoormiut gl
# ushuaia ar
# namibe ao
# bluff nz
# faanui pf
# lerwick gb
# tura ru
# chuy uy
# kavieng pg
# okhotsk ru
# lasa cn
# vaini to
# punta arenas cl
# provideniya ru
# saint-philippe re
# temiscaming ca
# bethel us
# port alfred za
# port moresby pg
# qaanaaq gl
# busselton au
# bengkulu id
# mataura pf
# yellowknife ca
# provideniya ru
# sola vu
# hokitika nz
# new norfolk au
# dharmavaram in
# puerto ayora ec
# punta arenas cl
# santo antonio do ica br
# ushuaia ar
# ushuaia ar
# rikitea pf
# tabou ci
# cape town za
# puerto ayora ec
# shenjiamen cn
# joshimath in
# rikitea pf
# vaini to
# kavieng pg
# dingle ie
# qaanaaq gl
# juneau us
# albany au
# barentsburg sj
# la ronge ca
# portland au
# illoqqortoormiut gl
# constantine dz
# norman wells ca
# provideniya ru
# kodiak us
# tuktoyaktuk ca
# victoria sc
# guerrero negro mx
# hobart au
# punta arenas cl
# hithadhoo mv
# hobart au
# clyde river ca
# rikitea pf
# kapaa us
# thompson ca
# ahipara nz
# chokurdakh ru
# inderborskiy kz
# albany au
# ushuaia ar
# georgetown sh
# inhambane mz
# ribeira grande pt
# talnakh ru
# sorland no
# sisimiut gl
# ayautla mx
# bluff nz
# saldanha za
# ushuaia ar
# hobart au
# carnarvon au
# amarkantak in
# roald no
# hilo us
# bredasdorp za
# san cristobal ec
# saint george bm
# hofn is
# hithadhoo mv
# ekibastuz kz
# moroto ug
# cape town za
# taolanaro mg
# komoro jp
# sorong id
# umm kaddadah sd
# kodiak us
# avarua ck
# ushuaia ar
# muisne ec
# barentsburg sj
# kaitangata nz
# vaini to
# mumford gh
# umm kaddadah sd
# ushuaia ar
# victoria sc
# iqaluit ca
# namibe ao
# arraial do cabo br
# eureka us
# oistins bb
# roebourne au
# mackay au
# beringovskiy ru
# kilmez ru
# provideniya ru
# palmer us
# mount gambier au
# jaisinghnagar in
# yar-sale ru
# kavaratti in
# mujiayingzi cn
# hilo us
# yellowknife ca
# fortuna us
# port alfred za
# ushuaia ar
# chuy uy
# preobrazheniye ru
# rikitea pf
# gweta bw
# atuona pf
# barcelos br
# ahipara nz
# provideniya ru
# ushuaia ar
# bara sd
# bom jesus br
# isangel vu
# siguiri gn
# laguna br
# nantucket us
# verkhoyansk ru
# tsihombe mg
# new norfolk au
# gat ly
# albany au
# coxim br
# mahebourg mu
# belushya guba ru
# barrow us
# sao joao da barra br
# havelock us
# lagoa pt
# hermanus za
# taolanaro mg
# iqaluit ca
# victoria sc
# rikitea pf
# tarakan id
# belushya guba ru
# toora-khem ru
# carnarvon au
# lubao cd
# cidreira br
# ushuaia ar
# netrakona bd
# powell river ca
# rikitea pf
# albany au
# beatrice us
# valparaiso cl
# olafsvik is
# atuona pf
# rikitea pf
# tasiilaq gl
# filadelfia py
# ushuaia ar
# atuona pf
# lukovetskiy ru
# mataura pf
# kenai us
# illoqqortoormiut gl
# canitas mx
# east london za
# codrington ag
# torbay ca
# hamilton bm
# jamestown sh
# port alfred za
# ahipara nz
# taolanaro mg
# new norfolk au
# codrington ag
# faanui pf
# jamestown sh
# zadar hr
# lompoc us
# mataura pf
# atuona pf
# bambous virieux mu
# rikitea pf
# saleaula ws
# punta arenas cl
# nikolskoye ru
# thompson ca
# esperance au
# port alfred za
# new norfolk au
# buala sb
# mataura pf
# new norfolk au
# saldanha za
# ribeira grande pt
# berdigestyakh ru
# tommot ru
# den helder nl
# port alfred za
# urengoy ru
# uroteppa tj
# rikitea pf
# vila velha br
# busselton au
# busselton au
# pasighat in
# lemesos cy
# baker city us
# bereda so
# sorvag fo
# punta arenas cl
# bredasdorp za
# port alfred za
# carnarvon au
# tasiilaq gl
# new norfolk au
# albany au
# saint-francois gp
# rocha uy
# lompoc us
# nikolskoye ru
# hilo us
# busselton au
# punta arenas cl
# vaini to
# new norfolk au
# kahului us
# castro cl
# blackwater au
# avera pf
# castro cl
# kapaa us
# kuvshinovo ru
# bathsheba bb
# samusu ws
# barrow us
# lompoc us
# san-pedro ci
# qaanaaq gl
# toliary mg
# mont-dore nc
# longyearbyen sj
# luau ao
# bathsheba bb
# bure et
# dombarovskiy ru
# sampit id
# taolanaro mg
# avarua ck
# jamestown sh
# sitka us
# kedougou sn
# hilo us
# sao gabriel da cachoeira br
# busselton au
# hasaki jp
# saint george bm
# abu samrah qa
# petropavlovsk-kamchatskiy ru
# punta arenas cl
# cape town za
# kruisfontein za
# rikitea pf
# lebu cl
# margate za
# gao ml
# veydelevka ru
# trairi br
# airai pw
# vostok ru
# mogadishu so
# rikitea pf
# vostok ru
# araouane ml
# ikere ng
# sorland no
# thompson ca
# coquimbo cl
# rikitea pf
# new norfolk au
# georgetown sh
# hermanus za
# karachi pk
# bluff nz
# kodiak us
# hermanus za
# mwingi ke
# cumaribo co
# busselton au
# chippewa falls us
# grand baie mu
# cidreira br
# ust-nera ru
# castro cl
# waingapu id
# tasiilaq gl
# luancheng cn
# pedernales do
# nikolskoye ru
# tsihombe mg
# beringovskiy ru
# vestmanna fo
# dikson ru
# rikitea pf
# tuktoyaktuk ca
# castro cl
# new norfolk au
# mangrol in
# grand gaube mu
# alzamay ru
# port-cartier ca
# qaanaaq gl
# rikitea pf
# vaini to
# port elizabeth za
# kavieng pg
# tiksi ru
# vaini to
# clyde river ca
# punta arenas cl
# montemarciano it
# port alfred za
# atuona pf
# prieska za
# iracoubo gf
# bubaque gw
# norman wells ca
# mataura pf
# lebu cl
# atar mr
# murmashi ru
# tiruchchendur in
# honningsvag no
# ushuaia ar
# busselton au
# faanui pf
# kempele fi
# los llanos de aridane es
# gangotri in
# malwan in
# rikitea pf
# chuy uy
# rocha uy
# namibe ao
# ormara pk
# victoria sc
# esperance au
# oktyabrskoye ru
# hit iq
# kidal ml
# rorvik no
# albany au
# rikitea pf
# yulara au
# taolanaro mg
# georgetown sh
# punta arenas cl
# acapulco mx
# taolanaro mg
# liwale tz
# albany au
# atuona pf
# nizhneyansk ru
# barentsburg sj
# palabuhanratu id
# nhulunbuy au
# jamestown sh
# caramay ph
# busselton au
# taolanaro mg
# rikitea pf
# quelimane mz
# kitoy ru
# bogorodskoye ru
# ushuaia ar
# punta arenas cl
# east london za
# castro cl
# huarmey pe
# sandwick gb
# narsaq gl
# kapaa us
# port alfred za
# hithadhoo mv
# cape town za
# whitehorse ca
# fortuna us
# atar mr
# hilo us
# fort saint james ca
# kapaa us
# pochutla mx
# kapaa us
# puerto ayora ec
# papayal pe
# bluff nz
# lokosovo ru
# khash ir
# esperance au
# ushuaia ar
# butaritari ki
# hilo us
# mendahara id
# muyezerskiy ru
# sentyabrskiy ru
# port alfred za
# mataura pf
# iqaluit ca
# belaya gora ru
# upernavik gl
# khatanga ru
# ipora br
# ventspils lv
# qaanaaq gl
# north bend us
# cairns au
# busselton au
# acapulco mx
# victoria sc
# portland au
# bluff nz
# sitka us
# saint-ambroise ca
# punta arenas cl
# pala td
# ushuaia ar
# bluff nz
# puerto ayora ec
# mar del plata ar
# puro ph
# albany au
# taolanaro mg
# mandan us
# quatre cocos mu
# saldanha za
# albany au
# mogadishu so
# atmakur in
# hithadhoo mv
# hithadhoo mv
# marzuq ly
# wajima jp
# taolanaro mg
# lompoc us
# upernavik gl
# quiindy py
# saint-philippe re
# nikolskoye ru
# rikitea pf
# okhotsk ru
# sitka us
# esperance au
# ushuaia ar
# jamestown sh
# busselton au
# albany au
# lumut my
# puri in
# san cristobal ve
# shelburne ca
# albany au
# verkhniy baskunchak ru
# punta arenas cl
# busselton au
# taolanaro mg
# barentsburg sj
# hermanus za
# ushuaia ar
# conneaut us
# te anau nz
# fomboni km
# eregli tr
# genhe cn
# yellowknife ca
# port blair in
# kapaa us
# arraial do cabo br
# kamaishi jp
# east london za
# vanimo pg
# punta arenas cl
# castro cl
# kommunisticheskiy ru
# provideniya ru
# umzimvubu za
# ushuaia ar
# cherskiy ru
# acarau br
# hella is
# port alfred za
# felidhoo mv
# mar del plata ar
# arraial do cabo br
# gold coast au
# krivosheino ru
# arman ru
# stoyba ru
# olinda br
# mataura pf
# jaisalmer in
# conakry gn
# esperance au
# makhinjauri ge
# te anau nz
# faanui pf
# bredasdorp za
# paamiut gl
# dryden ca
# bluff nz
# metro id
# nehe cn
# puerto ayora ec
# katsuura jp
# taolanaro mg
# abnub eg
# jamestown sh
# hobart au
# kahului us
# lagoa pt
# port elizabeth za
# hilo us
# nikolayevsk-na-amure ru
# le port re
# vila velha br
# bathsheba bb
# hasaki jp
# albany au
# georgetown sh
# samarai pg
# albany au
# kavaratti in
# punta arenas cl
# cape town za
# ushuaia ar
# rikitea pf
# sambava mg
# galle lk
# carutapera br
# qaanaaq gl
# punta arenas cl
# yining cn
# atuona pf
# murzzuschlag at
# jamestown sh
# longyearbyen sj
# broome au
# gat ly
# jamestown sh
# busselton au
# cape town za
# atuona pf
# san matias bo
# fort pierce us
# yumen cn
# port elizabeth za
# atuona pf
# cherskiy ru
# bathsheba bb
# teneguiban ph
# tiksi ru
# mataura pf
# boo se
# richards bay za
# bredasdorp za
# vaini to
# oga jp
# taolanaro mg
# butaritari ki
# basoko cd
# avarua ck
# albany au
# taolanaro mg
# hermanus za
# avarua ck
# sabang id
# lebu cl
# albany au
# ribeira grande pt
# ornskoldsvik se
# freeport us
# klaksvik fo
# nizhneyansk ru
# sibolga id
# hazorasp uz
# nioro ml
# hirara jp
# upernavik gl
# rikitea pf
# kalaleh ir
# port alfred za
# maulvi bazar bd
# albany au
# atuona pf
# mataura pf
# atuona pf
# ambilobe mg
# nizhneyansk ru
# ushuaia ar
# hobart au
# grindavik is
# punta arenas cl
# norman wells ca
# sentyabrskiy ru
# hithadhoo mv
# upernavik gl
# isangel vu
# tartus sy
# verkhoyansk ru
# punta arenas cl
# mount gambier au
# rikitea pf
# volkhovskiy ru
# mut tr
# punta arenas cl
# goderich sl
# rikitea pf
# ambovombe mg
# busselton au
# broken hill au
# mar del plata ar
# ushuaia ar
# leningradskiy ru
# mar del plata ar
# busselton au
# tukrah ly
# ushuaia ar
# mataura pf
# lavrentiya ru
# vaitupu wf
# hermanus za
# ushuaia ar
# alice springs au
# torgelow de
# lebu cl
# araouane ml
# rikitea pf
# hobart au
# tuktoyaktuk ca
# rikitea pf
# pontes e lacerda br
# hermanus za
# yaan cn
# samusu ws
# lebu cl
# amapa br
# kandrian pg
# barrow us
# mataura pf
# vila vu
# ushuaia ar
# bluff nz
# halalo wf
# san jose uy
# port hawkesbury ca
# mar del plata ar
# taolanaro mg
# sorland no
# fare pf
# bambous virieux mu
# bethel us
# canchungo gw
# half moon bay us
# beyneu kz
# ushuaia ar
# hermanus za
# faya td
# bay city us
# vaini to
# ntungamo ug
# port hardy ca
# punta arenas cl
# mataura pf
# fortuna us
# nyahururu ke
# barbar sd
# ouesso cg
# taolanaro mg
# attawapiskat ca
# asau tv
# rikitea pf
# albany au
# yaan cn
# neunkirchen de
# ganlose dk
# mataura pf
# pangai to
# jumla np
# kaitangata nz
# qaanaaq gl
# aubenas fr
# norman wells ca
# paamiut gl
# russell nz
# bardiyah ly
# tuktoyaktuk ca
# yellowknife ca
# plerin fr
# new norfolk au
# carnarvon za
# ushuaia ar
# sentyabrskiy ru
# barentsburg sj
# concepcion py
# jamestown sh
# cape town za
# belushya guba ru
# hermanus za
# port alfred za
# ushuaia ar
# vanimo pg
# itarema br
# bluff nz
# milkovo ru
# georgetown sh
# skelleftea se
# punta arenas cl
# rikitea pf
# tianpeng cn
# fortuna us
# avarua ck
# cidreira br
# inuvik ca
# rikitea pf
# nikolskoye ru
# saint-philippe re
# tsalenjikha ge
# sakaiminato jp
# ushuaia ar
# salamiyah sy
# turbat pk
# karamea nz
# arraial do cabo br
# kapaa us
# ribeira grande pt
# macenta gn
# east london za
# busselton au
# albany au
# usinsk ru
# chokurdakh ru
# neiafu to
# labuhan id
# marienburg sr
# port alfred za
# yellowknife ca
# hobart au
# saint-philippe re
# petropavlovsk-kamchatskiy ru
# rikitea pf
# mataura pf
# klaksvik fo
# mahebourg mu
# nhulunbuy au
# vila velha br
# busselton au
# cape town za
# rikitea pf
# jamestown sh
# port alfred za
# baykit ru
# bentiu sd
# coihaique cl
# kavieng pg
# san cristobal ec
# sinkat sd
# mar del plata ar
# umzimvubu za
# mys shmidta ru
# tiksi ru
# pitimbu br
# kaitangata nz
# tuktoyaktuk ca
# wasilla us
# tangshan cn
# hithadhoo mv
# halalo wf
# rikitea pf
# sioux lookout ca
# atuona pf
# mataura pf
# hirara jp
# umm kaddadah sd
# san roque ph
# deputatskiy ru
# hermanus za
# pevek ru
# galesong id
# marsh harbour bs
# vila velha br
# upernavik gl
# hilo us
# los llanos de aridane es
# vaini to
# languyan ph
# albany au
# innisfail au
# castro cl
# atuona pf
# nizhniy kuranakh ru
# ponta do sol cv
# grand gaube mu
# mataura pf
# vila velha br
# san patricio mx
# busselton au
# abilene us
# lanigan ca
# klaksvik fo
# mataura pf
# vaini to
# guerrero negro mx
# provideniya ru
# flinders au
# lebu cl
# puerto ayora ec
# butaritari ki
# busselton au
# sitka us
# ribeira grande pt
# taolanaro mg
# gazanjyk tm
# milan co
# kostelec nad orlici cz
# jalu ly
# taoudenni ml
# attawapiskat ca
# nabire id
# bonthe sl
# kieta pg
# jamestown sh
# mataura pf
# sao felix do xingu br
# kapaa us
# sai buri th
# hermanus za
# kermanshah ir
# valparaiso mx
# langham ca
# sao paulo de olivenca br
# ostrovnoy ru
# lata sb
# puerto ayora ec
# cherskiy ru
# caravelas br
# saint-georges gf
# punta arenas cl
# ancud cl
# luderitz na
# qaanaaq gl
# san quintin mx
# mareeba au
# saint-philippe re
# punta arenas cl
# rikitea pf
# kawalu id
# punta arenas cl
# san jeronimo mx
# mackay au
# mongoumba cf
# praya id
# hobart au
# barentsburg sj
# hirara jp
# ushuaia ar
# georgetown sh
# celestun mx
# sangar ru
# bhitarwar in
# ushuaia ar
# bluff nz
# airai pw
# tikhvin ru
# vestmanna fo
# woodward us
# san gabriel ph
# mar del plata ar
# hanyang cn
# albany au
# luderitz na
# georgetown sh
# el real de santa maria pa
# ca mau vn
# port keats au
# bani walid ly
# ushuaia ar
# gat ly
# kodiak us
# cherepovets ru
# ushuaia ar
# puerto ayora ec
# busselton au
# povoa de varzim pt
# bredasdorp za
# sentyabrskiy ru
# port alfred za
# cayenne gf
# celestun mx
# lasa cn
# teya ru
# kuching my
# touros br
# ambon id
# punta arenas cl
# albany au
# tual id
# ponta do sol pt
# barentsburg sj
# quatre cocos mu
# rikitea pf
# diu in
# belyy yar ru
# rostock de
# menongue ao
# longyearbyen sj
# busselton au
# nikolskoye ru
# atambua id
# tsihombe mg
# jamestown sh
# natitingou bj
# russell nz
# lagunillas ve
# airai pw
# ushuaia ar
# bluff nz
# haibowan cn
# upernavik gl
# puerto ayora ec
# manoel urbano br
# pecos us
# gat ly
# saldanha za
# ulladulla au
# port hedland au
# bahar ir
# yulara au
# cidreira br
# tenenkou ml
# quatre cocos mu
# dubbo au
# ushuaia ar
# mataura pf
# hobart au
# illoqqortoormiut gl
# cape town za
# mataura pf
# cap malheureux mu
# bluff nz
# darhan mn
# arraial do cabo br
# carnarvon au
# tema gh
# rikitea pf
# penzance gb
# puerto del rosario es
# mys shmidta ru
# atuona pf
# hermanus za
# tuktoyaktuk ca
# evensk ru
# cape town za
# new norfolk au
# rikitea pf
# rikitea pf
# dingle ie
# tuktoyaktuk ca
# samarai pg
# illoqqortoormiut gl
# mahebourg mu
# yellowknife ca
# blackwater au
# qaanaaq gl
# kupang id
# saint-augustin ca
# rikitea pf
# dikson ru
# chimbote pe
# churapcha ru
# poum nc
# severo-kurilsk ru
# albany au
# vila velha br
# katsuura jp
# barentsburg sj
# ushuaia ar
# kaeo nz
# arraial do cabo br
# batagay-alyta ru
# chokurdakh ru
# san patricio mx
# ruatoria nz
# rikitea pf
# qaanaaq gl
# kuche cn
# atuona pf
# rikitea pf
# kruisfontein za
# kropotkin ru
# touros br
# safaga eg
# faanui pf
# taolanaro mg
# barinitas ve
# pizarro co
# aloleng ph
# cap malheureux mu
# tuktoyaktuk ca
# rikitea pf
# punta arenas cl
# lompoc us
# kaitangata nz
# sitka us
# mareeba au
# doctor pedro p. pena py
# new norfolk au
# kudahuvadhoo mv
# bambous virieux mu
# nikolskoye ru
# severo-kurilsk ru
# sentyabrskiy ru
# broken hill au
# lebu cl
# hermanus za
# plymouth gb
# mandera ke
# jamestown sh
# casper us
# rikitea pf
# rikitea pf
# cherskiy ru

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 628

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f8a8f3743cd9de275d97a88345ed6688

# %%
# Create an endpoint URL for a city.
city_url = url + "&q=" + "Boston"
print(city_url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f8a8f3743cd9de275d97a88345ed6688&q=Boston

# %%
# Make a 'Get' request for the city weather.
city_weather = requests.get(city_url)
city_weather
# Out:
# <Response [200]>

# %%
city_weather.status_code
# Out:
# 200

# %%
# Create an endpoint URL for a city.
city_url = url + "&q=" + "Bston"
city_weather = requests.get(city_url)
city_weather
# Out:
# <Response [404]>

# %%
# Create an endpoint URL for a city.
city_url = url + "&q=" + "Boston"
city_weather = requests.get(city_url)
city_weather
# Out:
# <Response [200]>

# %%
# Get the text of the 'Get' request.
city_weather.text
# Out:
# '{"coord":{"lon":-71.06,"lat":42.36},"weather":[{"id":801,"main":"Clouds","description":"few clouds","icon":"02d"}],"base":"stations","main":{"temp":35.19,"feels_like":16.18,"temp_min":32,"temp_max":37.99,"pressure":1002,"humidity":59},"wind":{"speed":25.28,"deg":310,"gust":40.26},"clouds":{"all":17},"dt":1578244339,"sys":{"type":1,"id":4967,"country":"US","sunrise":1578226408,"sunset":1578259502},"timezone":-18000,"id":4930956,"name":"Boston","cod":200}'

# %%
# Get the JSON text of the 'Get' request.
city_weather.json()
# Out:
# {'coord': {'lon': -71.06, 'lat': 42.36},
#  'weather': [{'id': 801,
#    'main': 'Clouds',
#    'description': 'few clouds',
#    'icon': '02d'}],
#  'base': 'stations',
#  'main': {'temp': 35.19,
#   'feels_like': 16.18,
#   'temp_min': 32,
#   'temp_max': 37.99,
#   'pressure': 1002,
#   'humidity': 59},
#  'wind': {'speed': 25.28, 'deg': 310, 'gust': 40.26},
#  'clouds': {'all': 17},
#  'dt': 1578244339,
#  'sys': {'type': 1,
#   'id': 4967,
#   'country': 'US',
#   'sunrise': 1578226408,
#   'sunset': 1578259502},
#  'timezone': -18000,
#  'id': 4930956,
#  'name': 'Boston',
#  'cod': 200}

# %%
# Create an endpoint URL for a city.
city_url = url + "&q=" + "Boston"
city_weather = requests.get(city_url)
if city_weather.status_code == 200:
    print(f"City Weather found.")
else:
    print(f"City weather not found.")
# Out:
# City Weather found.

# %%
# Create an endpoint URL for a city.
city_url = url + "&q=" + "Bston"
city_weather = requests.get(city_url)
if city_weather.json():
    print(f"City Weather found.")
else:
    print(f"City weather not found.")
# Out:
# City Weather found.

# %%
print(city_url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f8a8f3743cd9de275d97a88345ed6688&q=Bston

# %%
# Create an endpoint URL for a city.
city_url = url + "&q=" + "Boston"
city_weather = requests.get(city_url)
city_weather.json()
# Out:
# {'coord': {'lon': -71.06, 'lat': 42.36},
#  'weather': [{'id': 801,
#    'main': 'Clouds',
#    'description': 'few clouds',
#    'icon': '02d'}],
#  'base': 'stations',
#  'main': {'temp': 35.19,
#   'feels_like': 16.18,
#   'temp_min': 32,
#   'temp_max': 37.99,
#   'pressure': 1002,
#   'humidity': 59},
#  'wind': {'speed': 25.28, 'deg': 310, 'gust': 40.26},
#  'clouds': {'all': 17},
#  'dt': 1578244339,
#  'sys': {'type': 1,
#   'id': 4967,
#   'country': 'US',
#   'sunrise': 1578226408,
#   'sunset': 1578259502},
#  'timezone': -18000,
#  'id': 4930956,
#  'name': 'Boston',
#  'cod': 200}

# %%
# Get the JSON data.
boston_data = city_weather.json()

# %%
boston_data['sys']
# Out:
# {'type': 1,
#  'id': 4967,
#  'country': 'US',
#  'sunrise': 1578226408,
#  'sunset': 1578259502}

# %%
boston_data["sys"]["country"]
# Out:
# 'US'

# %%
boston_data["dt"]
# Out:
# 1578244339

# %%
lat = boston_data["coord"]["lat"]
lng = boston_data["coord"]["lon"]
max_temp = boston_data["main"]["temp_max"]
humidity = boston_data["main"]["humidity"]
clouds = boston_data["clouds"]["all"]
wind = boston_data["wind"]["speed"]
print(lat, lng, max_temp, humidity, clouds, wind)
# Out:
# 42.36 -71.06 37.99 59 17 25.28

# %%
boston_data["dt"]
# Out:
# 1578244339

# %%
# Import the datetime module from the datetime library.
from datetime import datetime
# Get the date from the JSON file.
date = boston_data["dt"]
# Convert the UTC date to a date format with year, month, day, hours, minutes, and seconds.
datetime.utcfromtimestamp(date).strftime('%Y-%m-%d %H:%M:%S')
# Out:
# '2020-01-05 17:12:19'
