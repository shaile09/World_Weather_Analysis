# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Create a practice set of random latitude and longitude combinations.
x = [25.12903645, 25.92017388, 26.62509167, -59.98969384, 37.30571269]
y = [-67.59741259, 11.09532135, 74.84233102, -76.89176677, -61.13376282]
coordinates = zip(x, y)

# %%
# Use the tuple() function to display the latitude and longitude combinations.
for coordinate in coordinates:
    print(coordinate[0], coordinate[1])
# Out:
# 25.12903645 -67.59741259
# 25.92017388 11.09532135
# 26.62509167 74.84233102
# -59.98969384 -76.89176677
# 37.30571269 -61.13376282

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# %%
# Use the tuple() function to display the latitude and longitude combinations.
for coordinate in coordinates:
    print(citipy.nearest_city(coordinate[0], coordinate[1]).city_name,
          citipy.nearest_city(coordinate[0], coordinate[1]).country_code)
# Out:
# tansen np
# vestmannaeyjar is
# port hedland au
# souillac mu
# nioro ml
# luderitz na
# bukama cd
# auki sb
# viedma ar
# vila franca do campo pt
# albany au
# ushuaia ar
# hamilton bm
# georgetown sh
# bambous virieux mu
# arraial do cabo br
# saint-pierre pm
# saint combs gb
# riyadh sa
# hermanus za
# fortuna us
# ampanihy mg
# talavera de la reina es
# tasiilaq gl
# jiangyou cn
# east london za
# butaritari ki
# nikolskoye ru
# lockhart us
# butaritari ki
# carnarvon au
# saleaula ws
# saleaula ws
# lexington us
# inhambane mz
# klaksvik fo
# port alfred za
# port alfred za
# hobart au
# acapulco mx
# atuona pf
# dvinskoy ru
# busselton au
# bredasdorp za
# jamestown sh
# hithadhoo mv
# kazalinsk kz
# bambous virieux mu
# dien bien vn
# rikitea pf
# codrington ag
# whitehorse ca
# hobart au
# bengkulu id
# kushima jp
# kloulklubed pw
# barentsburg sj
# busselton au
# mabaruma gy
# eyl so
# ushuaia ar
# nanortalik gl
# kavieng pg
# tucumcari us
# taolanaro mg
# saint-francois gp
# gat ly
# kamenskoye ru
# ilulissat gl
# mataura pf
# barrow us
# ahuimanu us
# saint-philippe re
# port alfred za
# bluff nz
# sentyabrskiy ru
# codrington ag
# kapaa us
# serik tr
# saleaula ws
# la union es
# illoqqortoormiut gl
# bagh in
# ushuaia ar
# georgetown sh
# kapaa us
# portland au
# punta arenas cl
# nagyhalasz hu
# qaanaaq gl
# riyadh sa
# hilo us
# east london za
# illoqqortoormiut gl
# avarua ck
# saint george bm
# qaanaaq gl
# hihifo to
# hilo us
# ushuaia ar
# albany au
# cape town za
# tsihombe mg
# leningradskiy ru
# bambous virieux mu
# shirokiy ru
# talnakh ru
# vestmannaeyjar is
# uyuni bo
# oyama jp
# illoqqortoormiut gl
# taolanaro mg
# thinadhoo mv
# mar del plata ar
# busselton au
# qaanaaq gl
# ushuaia ar
# galle lk
# carnot cf
# puerto ayora ec
# roebourne au
# boca do acre br
# rikitea pf
# nelson bay au
# ushuaia ar
# ushuaia ar
# atuona pf
# attawapiskat ca
# san jeronimo de tunan pe
# portland au
# inhambane mz
# yellowknife ca
# nikolskoye ru
# ushuaia ar
# yellowknife ca
# puerto ayora ec
# pevek ru
# sampit id
# ulladulla au
# punta arenas cl
# georgetown sh
# kalabo zm
# saldanha za
# kapaa us
# morgan city us
# grand river south east mu
# georgetown sh
# illoqqortoormiut gl
# tuatapere nz
# agirish ru
# barrow us
# avarua ck
# saskylakh ru
# ushuaia ar
# saint-philippe re
# lompoc us
# saskylakh ru
# bilma ne
# guerrero negro mx
# praia da vitoria pt
# ipixuna br
# san cristobal ec
# yellowknife ca
# bredasdorp za
# sharan ru
# thompson ca
# sinegorye ru
# ilulissat gl
# lerwick gb
# ushuaia ar
# asayita et
# ushuaia ar
# busselton au
# wanparti in
# ushuaia ar
# vaini to
# new norfolk au
# illoqqortoormiut gl
# puerto ayora ec
# airai pw
# bluff nz
# thompson ca
# rawson ar
# vaini to
# ushuaia ar
# nishihara jp
# san cristobal ec
# mataura pf
# haines junction ca
# busselton au
# busselton au
# atuona pf
# flint us
# mataura pf
# utiroa ki
# cape town za
# klaksvik fo
# kindersley ca
# jamestown sh
# ossora ru
# port alfred za
# vieux-habitants gp
# puerto ayora ec
# rikitea pf
# saleaula ws
# ancud cl
# emerald au
# mys shmidta ru
# fort nelson ca
# tura ru
# vaitape pf
# saint-philippe re
# yellowknife ca
# provideniya ru
# taolanaro mg
# rikitea pf
# saleaula ws
# talnakh ru
# ovalle cl
# kamenka ru
# daru pg
# kiruna se
# punta arenas cl
# lorengau pg
# petropavlovsk-kamchatskiy ru
# taolanaro mg
# castro cl
# georgetown sh
# minab ir
# vanimo pg
# ushuaia ar
# romans-sur-isere fr
# samusu ws
# cape town za
# vaini to
# bredasdorp za
# upernavik gl
# hermanus za
# hermanus za
# hobart au
# jibuti dj
# half moon bay us
# rikitea pf
# reinosa es
# manta ec
# sao filipe cv
# san quintin mx
# tatawin tn
# ushuaia ar
# punta arenas cl
# ca mau vn
# mar del plata ar
# bubaque gw
# saint-philippe re
# avarua ck
# saldanha za
# martapura id
# nizhneyansk ru
# avarua ck
# bambous virieux mu
# grand island us
# longyearbyen sj
# matagami ca
# havoysund no
# santa cruz cr
# hualmay pe
# puerto ayora ec
# isangel vu
# juybar ir
# jamestown sh
# bengkulu id
# muros es
# santa catarina de tepehuanes mx
# henties bay na
# mataura pf
# ancud cl
# barentsburg sj
# ecoporanga br
# hermanus za
# butaritari ki
# barrow us
# punta arenas cl
# kralendijk an
# puerto ayora ec
# sentyabrskiy ru
# east london za
# dianopolis br
# opuwo na
# kruisfontein za
# kapaa us
# karpathos gr
# saint george bm
# fortuna us
# karaul ru
# saskylakh ru
# baudh in
# ushuaia ar
# kulunda ru
# barrow us
# ushuaia ar
# punta arenas cl
# zyryanka ru
# ahipara nz
# voyvozh ru
# kaitangata nz
# zhangye cn
# bima id
# rancho palos verdes us
# longyearbyen sj
# bathsheba bb
# montrose us
# khatanga ru
# daru pg
# carroll us
# komsomolskiy ru
# albany au
# sao gabriel da cachoeira br
# hithadhoo mv
# eirunepe br
# port alfred za
# kuala lumpur my
# qui nhon vn
# hithadhoo mv
# yellowknife ca
# pedernales do
# sorland no
# kutum sd
# punta arenas cl
# mataura pf
# mataura pf
# punta arenas cl
# nabire id
# andenes no
# puerto escondido mx
# jamestown sh
# nizhneyansk ru
# nizhneyansk ru
# hobart au
# nikolskoye ru
# cidreira br
# cape town za
# kargat ru
# east london za
# ribeira grande pt
# bengkulu id
# upernavik gl
# bluff nz
# halmstad se
# buqayq sa
# itarema br
# cape town za
# the valley ai
# hithadhoo mv
# kodiak us
# albany au
# high prairie ca
# busselton au
# atuona pf
# san patricio mx
# pevek ru
# mys shmidta ru
# rikitea pf
# hermanus za
# ribeira grande pt
# kodiak us
# hasaki jp
# roald no
# kapaa us
# calamar co
# attawapiskat ca
# khatanga ru
# rikitea pf
# saldanha za
# mataura pf
# albany au
# ushuaia ar
# hilo us
# kruisfontein za
# nanortalik gl
# rikitea pf
# albany au
# hobart au
# qaanaaq gl
# arraial do cabo br
# hithadhoo mv
# ancud cl
# longyearbyen sj
# bredasdorp za
# rikitea pf
# saint-philippe re
# albany au
# atuona pf
# linden gy
# fortuna us
# jamestown sh
# luderitz na
# atuona pf
# belushya guba ru
# arraial do cabo br
# inhambane mz
# albany au
# mandera ke
# adre td
# mataura pf
# tawkar sd
# comodoro rivadavia ar
# provideniya ru
# provideniya ru
# turukhansk ru
# quedlinburg de
# rikitea pf
# busselton au
# severo-kurilsk ru
# ushuaia ar
# river falls us
# busselton au
# vaini to
# bluff nz
# mar del plata ar
# salalah om
# pevek ru
# port elgin ca
# arraial do cabo br
# saint-philippe re
# cape town za
# barrow us
# matagami ca
# airai pw
# bac lieu vn
# sorland no
# katsuura jp
# jalu ly
# comodoro rivadavia ar
# chokurdakh ru
# barrow us
# mount gambier au
# qaanaaq gl
# punta arenas cl
# atuona pf
# mataura pf
# yellowknife ca
# saint-philippe re
# illoqqortoormiut gl
# egvekinot ru
# barentsburg sj
# saskylakh ru
# busselton au
# vaini to
# punta arenas cl
# provideniya ru
# nikolskoye ru
# vila franca do campo pt
# verkhnevilyuysk ru
# thanh hoa vn
# maragogi br
# illoqqortoormiut gl
# mataura pf
# jamestown sh
# bluff nz
# marcona pe
# taolanaro mg
# busselton au
# tasiilaq gl
# arraial do cabo br
# banda aceh id
# soyo ao
# busselton au
# bur gabo so
# ust-kamchatsk ru
# carnarvon au
# mataura pf
# codrington ag
# illoqqortoormiut gl
# soyo ao
# shingu jp
# vaini to
# saldanha za
# hermanus za
# jadu ly
# los llanos de aridane es
# mataura pf
# luderitz na
# nyaunglebin mm
# upernavik gl
# dunedin nz
# punta arenas cl
# mehamn no
# harrison us
# mataura pf
# rengo cl
# luderitz na
# broome au
# griffith au
# waitati nz
# saquena pe
# umzimvubu za
# swan river ca
# vaini to
# hobart au
# okhotsk ru
# punta arenas cl
# kamareddi in
# albany au
# qaanaaq gl
# port alfred za
# punta arenas cl
# haikou cn
# rikitea pf
# tanete id
# tasiilaq gl
# leningradskiy ru
# paris us
# bluff nz
# busselton au
# tungkang tw
# busselton au
# barrow us
# vaini to
# pimenta bueno br
# bredasdorp za
# sobolevo ru
# rikitea pf
# busselton au
# lazaro cardenas mx
# vaini to
# sergeyevka kz
# vanimo pg
# mataura pf
# barrow us
# khatanga ru
# rikitea pf
# busselton au
# karratha au
# ushuaia ar
# busselton au
# mantua cu
# college us
# ushuaia ar
# chhabra in
# east london za
# saint-joseph re
# puerto colombia co
# longyearbyen sj
# kavieng pg
# cape town za
# torbay ca
# tabuk sa
# punta arenas cl
# clyde river ca
# tuatapere nz
# nanortalik gl
# tsihombe mg
# martapura id
# tuy hoa vn
# hermanus za
# peniche pt
# san ramon bo
# santiago del estero ar
# nanortalik gl
# bredasdorp za
# grindavik is
# hami cn
# vao nc
# san antonio cl
# brae gb
# port hedland au
# arman ru
# zhigansk ru
# yeniseysk ru
# rikitea pf
# sangueya gn
# bengkulu id
# miri my
# nishihara jp
# bose cn
# provideniya ru
# souillac mu
# umea se
# shimoda jp
# tretten no
# bontang id
# khatanga ru
# ukiah us
# new norfolk au
# tsihombe mg
# carnarvon au
# albany au
# grand gaube mu
# atuona pf
# bredasdorp za
# boa vista br
# east london za
# kodiak us
# ha tinh vn
# sisophon kh
# talara pe
# razole in
# sept-iles ca
# rikitea pf
# yellowknife ca
# thompson ca
# kapaa us
# rikitea pf
# chifeng cn
# jinxiang cn
# yulara au
# guerrero negro mx
# punta arenas cl
# cape town za
# mataura pf
# dunedin nz
# ushuaia ar
# saint-philippe re
# port-cartier ca
# tuktoyaktuk ca
# nizhneyansk ru
# punta arenas cl
# qurayyat om
# hermanus za
# kodiak us
# tura ru
# bulgan mn
# bogovarovo ru
# castro cl
# port blair in
# castro cl
# saskylakh ru
# coquimbo cl
# vaini to
# manggar id
# port alfred za
# kromy ru
# mataura pf
# atuona pf
# bredasdorp za
# jinchengjiang cn
# albany au
# ancud cl
# koungou yt
# mataura pf
# labuhan id
# ust-omchug ru
# victoria sc
# narsaq gl
# coihaique cl
# severnyy ru
# ushuaia ar
# cape town za
# busselton au
# illoqqortoormiut gl
# bengkulu id
# fairbanks us
# ixtapa mx
# pevek ru
# bethel us
# punta arenas cl
# rikitea pf
# barrow us
# punta arenas cl
# puteyets ru
# ushuaia ar
# khatanga ru
# katsuura jp
# praya id
# puerto ayora ec
# bluff nz
# puerto leguizamo co
# vostok ru
# richards bay za
# oakham gb
# champerico gt
# baruun-urt mn
# sitka us
# roma au
# suksun ru
# nara ml
# saint george bm
# basar in
# takoradi gh
# ahipara nz
# lorengau pg
# ushuaia ar
# mar del plata ar
# manokwari id
# khatanga ru
# amboasary mg
# ca mau vn
# kalat pk
# chuy uy
# hermanus za
# butaritari ki
# ushuaia ar
# puerto ayora ec
# sept-iles ca
# fernley us
# albany au
# tabou ci
# sayat tm
# tuktoyaktuk ca
# ostrovnoy ru
# saint-philippe re
# illoqqortoormiut gl
# punta arenas cl
# ushuaia ar
# thompson ca
# tuchkovo ru
# sitka us
# arraial do cabo br
# barcelona ve
# saskylakh ru
# mataura pf
# linhares br
# hilo us
# klaksvik fo
# mar del plata ar
# norman wells ca
# rikitea pf
# bambous virieux mu
# adrar dz
# roald no
# saldanha za
# hobart au
# vaitupu wf
# sinnamary gf
# pouebo nc
# new norfolk au
# qaanaaq gl
# george za
# grand river south east mu
# bilibino ru
# puerto ayora ec
# vaini to
# cape town za
# souillac mu
# bredasdorp za
# saint george bm
# san jeronimo mx
# champerico gt
# pangnirtung ca
# mayo ca
# albany au
# vaini to
# saleaula ws
# bubaque gw
# rikitea pf
# mount pleasant us
# komsomolskiy ru
# chuy uy
# rikitea pf
# ust-nera ru
# zverinogolovskoye ru
# dikson ru
# shimoda jp
# vila do maio cv
# rikitea pf
# severnyy-kospashskiy ru
# yellowknife ca
# belushya guba ru
# provideniya ru
# luderitz na
# vaini to
# souillac mu
# taolanaro mg
# dikson ru
# starachowice pl
# darhan mn
# kalmunai lk
# hobart au
# kodiak us
# kapaa us
# teya ru
# naze jp
# busselton au
# shimoda jp
# marsh harbour bs
# plettenberg bay za
# barrow us
# bredasdorp za
# punta arenas cl
# bluff nz
# rikitea pf
# fairbanks us
# punta arenas cl
# clairmont ca
# puerto ayora ec
# kapaa us
# praia da vitoria pt
# ilulissat gl
# busselton au
# mar del plata ar
# nikolskoye ru
# ushuaia ar
# himora et
# rikitea pf
# kapaa us
# puerto leguizamo co
# mataura pf
# atuona pf
# albany au
# ushuaia ar
# hithadhoo mv
# cidreira br
# barra do garcas br
# saskylakh ru
# ancud cl
# pisco pe
# vila velha br
# caiaponia br
# saskylakh ru
# castro cl
# castro cl
# bredasdorp za
# cherskiy ru
# illoqqortoormiut gl
# rikitea pf
# busselton au
# sitrah bh
# hilo us
# avera pf
# busselton au
# luwuk id
# pevek ru
# corn island ni
# urengoy ru
# cap malheureux mu
# souillac mu
# ust-kamchatsk ru
# nemuro jp
# busselton au
# yellowknife ca
# kuhestan af
# hermanus za
# katsuura jp
# punta arenas cl
# arraial do cabo br
# beidao cn
# ketchikan us
# ushuaia ar
# busselton au
# chuy uy
# ossora ru
# vaini to
# san patricio mx
# albany au
# port elizabeth za
# provideniya ru
# busselton au
# wamba cd
# ushuaia ar
# cape town za
# ushuaia ar
# sola vu
# vigrestad no
# anadyr ru
# saldanha za
# port alfred za
# kapaa us
# tecoanapa mx
# beringovskiy ru
# torbay ca
# qaanaaq gl
# kapaa us
# beisfjord no
# hermanus za
# touros br
# albany au
# kodiak us
# port hedland au
# busselton au
# karratha au
# ushuaia ar
# prince rupert ca
# narsaq gl
# taolanaro mg
# jamestown sh
# mataura pf
# hay river ca
# poum nc
# port pirie au
# butaritari ki
# jamestown sh
# albany au
# taolanaro mg
# nampula mz
# faanui pf
# albany au
# busselton au
# qaanaaq gl
# bengkulu id
# zyryanka ru
# rikitea pf
# bredasdorp za
# gull lake ca
# iquique cl
# alofi nu
# longlac ca
# nizhneyansk ru
# punta arenas cl
# tocopilla cl
# port alfred za
# hauterive ca
# castro cl
# east london za
# elliot lake ca
# vaitupu wf
# talnakh ru
# busselton au
# mufumbwe zm
# puerto ayora ec
# ostrovnoy ru
# solnechnyy ru
# kahului us
# jishou cn
# busselton au
# albany au
# tarut sa
# arraial do cabo br
# puerto ayora ec
# buraydah sa
# sur om
# mullaitivu lk
# jamestown sh
# hilo us
# kapaa us
# rikitea pf
# upernavik gl
# carnarvon au
# changping cn
# chuy uy
# airai pw
# hithadhoo mv
# yar-sale ru
# edson ca
# hermanus za
# bathsheba bb
# ajdabiya ly
# kununurra au
# rikitea pf
# nome us
# ajdabiya ly
# bilibino ru
# hermanus za
# taolanaro mg
# leningradskiy ru
# stokmarknes no
# iqaluit ca
# rikitea pf
# vaini to
# san vicente ph
# mataura pf
# bredasdorp za
# kavaratti in
# hilo us
# komsomolskiy ru
# cockburn town bs
# hithadhoo mv
# qaanaaq gl
# airai pw
# kapaa us
# mastic beach us
# enshi cn
# la brea pe
# kaitangata nz
# samaro pk
# kristiinankaupunki fi
# pyaozerskiy ru
# illoqqortoormiut gl
# popondetta pg
# nichinan jp
# anadyr ru
# mataura pf
# chuy uy
# mar del plata ar
# vinh vn
# hermanus za
# padang id
# punta arenas cl
# issoudun fr
# tasiilaq gl
# mount isa au
# fortuna us
# hervey bay au
# rikitea pf
# port alfred za
# port alfred za
# port elizabeth za
# bathsheba bb
# bethel us
# jiuquan cn
# richards bay za
# tasiilaq gl
# mataura pf
# punta arenas cl
# sorrento it
# petropavlovsk-kamchatskiy ru
# gizo sb
# saskylakh ru
# itarema br
# oksovskiy ru
# kangaatsiaq gl
# port alfred za
# lamar us
# grand river south east mu
# new norfolk au
# nyurba ru
# bilyayivka ua
# bambous virieux mu
# saskylakh ru
# rikitea pf
# ponta do sol cv
# qaqortoq gl
# kelso us
# vaini to
# busselton au
# illoqqortoormiut gl
# busselton au
# olafsvik is
# ola ru
# mahebourg mu
# busselton au
# belushya guba ru
# nemuro jp
# kodiak us
# moose factory ca
# dingle ie
# saleaula ws
# linxia cn
# norman wells ca
# vaini to
# saskylakh ru
# butaritari ki
# road town vg
# carnarvon au
# grand river south east mu
# guerrero negro mx
# avarua ck
# singaraja id
# klaksvik fo
# tiksi ru
# chern ru
# carnarvon au
# lithakia gr
# taolanaro mg
# saint george bm
# kodiak us
# mataura pf
# dikson ru
# samusu ws
# ushuaia ar
# rikitea pf
# vaini to
# mabaruma gy
# sentyabrskiy ru
# avarua ck
# ushuaia ar
# atuona pf
# elat il
# bluff nz
# kulu in
# cap malheureux mu
# hithadhoo mv
# qaanaaq gl
# cape town za
# vaitupu wf
# amderma ru
# vaini to
# ribeira grande pt
# port alfred za
# jiuquan cn
# kontagora ng
# qaanaaq gl
# saint-philippe re
# provideniya ru
# kapaa us
# vogan tg
# port-cartier ca
# tiksi ru
# tasiilaq gl
# mataura pf
# cape town za
# avarua ck
# taolanaro mg
# ribeirao bonito br
# busselton au
# osmena ph
# atuona pf
# cabo san lucas mx
# jinchang cn
# kentau kz
# longyearbyen sj
# haines junction ca
# qaanaaq gl
# beihai cn
# port lincoln au
# deer lake ca
# grindavik is
# taolanaro mg
# port elizabeth za
# puerto ayora ec
# matamoros mx
# upernavik gl
# chuy uy
# cape town za
# busselton au
# bluff nz
# punta arenas cl
# busselton au
# punta arenas cl
# hobart au
# angoche mz
# bethel us
# albany au
# kapaa us
# klaksvik fo
# east london za
# rovaniemi fi
# port elizabeth za
# guerrero negro mx
# tingi tz
# punta arenas cl
# bathsheba bb
# cabo san lucas mx
# sola vu
# norman wells ca
# palabuhanratu id
# hilo us
# sumenep id
# nago jp
# bredasdorp za
# alenquer br
# rikitea pf
# ust-nera ru
# killeen us
# ewa beach us
# cidreira br
# kucevo rs
# upernavik gl
# lavrentiya ru
# saldanha za
# vanino ru
# illoqqortoormiut gl
# kodiak us
# san patricio mx
# mackay au
# busselton au
# thompson ca
# baghdad iq
# vaini to
# katsuura jp
# iralaya hn
# rikitea pf
# taolanaro mg
# shubarshi kz
# lata sb
# buta cd
# longyearbyen sj
# ushuaia ar
# dien bien vn
# grand river south east mu
# barentsburg sj
# puerto ayora ec
# jamestown sh
# vaini to
# east london za
# new norfolk au
# kavieng pg
# barentsburg sj
# cherskiy ru
# cananeia br
# north bend us
# cagayan de tawi-tawi ph
# chuy uy
# karomatan ph
# saskylakh ru
# santa isabel us
# atuona pf
# sobolevo ru
# albany au
# tautira pf
# whitehorse ca
# tiksi ru
# taolanaro mg
# rikitea pf
# rikitea pf
# vaini to
# ushuaia ar
# kodiak us
# nantucket us
# rikitea pf
# shitkino ru
# mineiros br
# punta arenas cl
# payson us
# marrakesh ma
# bethel us
# mount pleasant us
# carnarvon au
# erzin ru
# luanda ao
# bluff nz
# rikitea pf
# mahebourg mu
# fairbanks us
# paamiut gl
# faanui pf
# kruisfontein za
# takoradi gh
# hilo us
# rikitea pf
# asau tv
# tsihombe mg
# gayny ru
# haicheng cn
# ushuaia ar
# bluff nz
# ushuaia ar
# moose factory ca
# zolotukhino ru
# mahebourg mu
# tasiilaq gl
# hilo us
# bluff nz
# amderma ru
# show low us
# santa maria cv
# dunedin nz
# butaritari ki
# sena madureira br
# rikitea pf
# atuona pf
# airai pw
# punta arenas cl
# ushuaia ar
# aykhal ru
# hobyo so
# svetlogorsk ru
# yellowknife ca
# killybegs ie
# kampong thum kh
# nikolskoye ru
# bredasdorp za
# rikitea pf
# nizhneyansk ru
# tecoanapa mx
# aklavik ca
# east london za
# lompoc us
# busselton au
# busselton au
# hilo us
# ushuaia ar
# kapaa us
# mar del plata ar
# myitkyina mm
# dingle ie
# rikitea pf
# ushuaia ar
# barrow us
# ushuaia ar
# hilo us
# bambous virieux mu
# busselton au
# tianpeng cn
# batagay ru
# bredasdorp za
# san cristobal ec
# avarua ck
# pacific grove us
# puerto ayora ec
# vardo no
# melito di porto salvo it
# baruun-urt mn
# new norfolk au
# slave lake ca
# puerto ayora ec
# nikolskoye ru
# chokurdakh ru
# vila franca do campo pt
# esperance au
# illoqqortoormiut gl
# mountain home us
# arraial do cabo br
# busselton au
# tual id
# avarua ck
# illoqqortoormiut gl
# busselton au
# flinders au
# qaanaaq gl
# namibe ao
# acarau br
# tukrah ly
# taltal cl
# busselton au
# ushuaia ar
# puerto ayora ec
# punta arenas cl
# port elizabeth za
# hobart au
# albany au
# faanui pf
# krasnoye-na-volge ru
# statesville us
# dianopolis br
# hilo us
# taolanaro mg
# chernushka ru
# ushuaia ar
# arraial do cabo br
# jamestown sh
# sao filipe cv
# arraial do cabo br
# saint-philippe re
# nuevitas cu
# mataura pf
# tsihombe mg
# tasiilaq gl
# roald no
# puerto ayora ec
# ushuaia ar
# jamestown sh
# sestao es
# nikolskoye ru
# ushuaia ar
# college us
# provideniya ru
# rikitea pf
# constitucion mx
# santa isabel us
# carnarvon au
# new norfolk au
# lebu cl
# talara pe
# busselton au
# mataura pf
# tiksi ru
# port alfred za
# rikitea pf
# salekhard ru
# bluff nz
# ushuaia ar
# talnakh ru
# sentyabrskiy ru
# pangnirtung ca
# mukhen ru
# vila velha br
# chernyshevskiy ru
# kirkland lake ca
# cidreira br
# attawapiskat ca
# busselton au
# ponta do sol cv
# nikolskoye ru
# novyy urengoy ru
# salta ar
# bonthe sl
# milingimbi au
# bundaberg au
# launceston au
# margate za
# mataura pf
# dawei mm
# hasaki jp
# omsukchan ru
# ushuaia ar
# porto novo cv
# port alfred za
# sitka us
# poum nc
# mataura pf
# borba br
# bagdarin ru
# yulara au
# ushuaia ar
# rikitea pf
# beloha mg
# kavaratti in
# dingle ie
# sechura pe
# port alfred za
# rikitea pf
# bluff nz
# college us
# beringovskiy ru
# taolanaro mg
# iqaluit ca
# kapaa us
# whitianga nz
# borama so
# quelimane mz
# busselton au
# cape town za
# tuktoyaktuk ca
# cabo san lucas mx
# clyde river ca
# sentyabrskiy ru
# barrow us
# viedma ar
# bluff nz
# catamarca ar
# rikitea pf
# mbuji-mayi cd
# lompoc us
# kapaa us
# saint-philippe re
# hilo us
# sentyabrskiy ru
# bredasdorp za
# karratha au
# dunedin nz
# chokurdakh ru
# jos ng
# hithadhoo mv
# kirakira sb
# ushuaia ar
# port-cartier ca
# mys shmidta ru
# roma au
# busselton au
# yenagoa ng
# padang id
# hilo us
# ushuaia ar
# sosnovka ru
# atuona pf
# zhuanghe cn
# east london za
# illoqqortoormiut gl
# chifeng cn
# bredasdorp za
# atuona pf
# iqaluit ca
# viedma ar
# bluff nz
# winnemucca us
# sentyabrskiy ru
# yirol sd
# kapaa us
# leh in
# komsomolskiy ru
# airai pw
# tolaga bay nz
# zabid ye
# bredasdorp za
# ushuaia ar
# provideniya ru
# ostrovnoy ru
# iqaluit ca
# rikitea pf
# belushya guba ru
# shache cn
# illoqqortoormiut gl
# bonito br
# ushuaia ar
# surovikino ru
# upernavik gl
# upernavik gl
# taolanaro mg
# albany au
# barrow us
# rikitea pf
# cam ranh vn
# barrow us
# georgetown sh
# khatanga ru
# castro cl
# bluff nz
# kavieng pg
# shelburne ca
# mataura pf
# moose factory ca
# illoqqortoormiut gl
# ixtapa mx
# pisco pe
# sao miguel do araguaia br
# mechanicsville us
# puri in
# stornoway gb
# daru pg
# bengkulu id
# helena us
# disna by
# punta arenas cl
# mao td
# ponta do sol cv
# tsihombe mg
# mataura pf
# tongren cn
# rio grande br
# ostrovnoy ru
# san rafael del sur ni
# belmonte br
# kodiak us
# narsaq gl
# ushuaia ar
# marica br
# mar del plata ar
# luderitz na
# vaini to
# buraydah sa

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 598

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=eb273abd97be6fe0052f516f1f4d8101

# %%
# Create an endpoint URL for a city.
city_url = url + "&q=" + "Boston"
print(city_url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=eb273abd97be6fe0052f516f1f4d8101&q=Boston

# %%
# Make a 'Get' request for the city weather.
city_weather = requests.get(city_url)
city_weather
# Out:
# <Response [200]>

# %%
city_weather.status_code
# Out:
# 200

# %%
# Create an endpoint URL for a city.
city_url = url + "&q=" + "Bston"
city_weather = requests.get(city_url)
city_weather
# Out:
# <Response [404]>

# %%
# Create an endpoint URL for a city.
city_url = url + "&q=" + "Boston"
city_weather = requests.get(city_url)
city_weather
# Out:
# <Response [200]>

# %%
# Get the text of the 'Get' request.
city_weather.text
# Out:
# '{"coord":{"lon":-71.06,"lat":42.36},"weather":[{"id":800,"main":"Clear","description":"clear sky","icon":"01n"}],"base":"stations","main":{"temp":40.06,"feels_like":32.07,"temp_min":33.01,"temp_max":46.4,"pressure":1010,"humidity":75},"visibility":16093,"wind":{"speed":8.05,"deg":220},"clouds":{"all":1},"dt":1578020163,"sys":{"type":1,"id":4210,"country":"US","sunrise":1577967208,"sunset":1578000140},"timezone":-18000,"id":4930956,"name":"Boston","cod":200}'

# %%
# Get the JSON text of the 'Get' request.
city_weather.json()
# Out:
# {'coord': {'lon': -71.06, 'lat': 42.36},
#  'weather': [{'id': 800,
#    'main': 'Clear',
#    'description': 'clear sky',
#    'icon': '01n'}],
#  'base': 'stations',
#  'main': {'temp': 40.06,
#   'feels_like': 32.07,
#   'temp_min': 33.01,
#   'temp_max': 46.4,
#   'pressure': 1010,
#   'humidity': 75},
#  'visibility': 16093,
#  'wind': {'speed': 8.05, 'deg': 220},
#  'clouds': {'all': 1},
#  'dt': 1578020163,
#  'sys': {'type': 1,
#   'id': 4210,
#   'country': 'US',
#   'sunrise': 1577967208,
#   'sunset': 1578000140},
#  'timezone': -18000,
#  'id': 4930956,
#  'name': 'Boston',
#  'cod': 200}

# %%
# Create an endpoint URL for a city.
city_url = url + "&q=" + "Boston"
city_weather = requests.get(city_url)
if city_weather.status_code == 200:
    print(f"City Weather found.")
else:
    print(f"City weather not found.")
# Out:
# City Weather found.

# %%
# Create an endpoint URL for a city.
city_url = url + "&q=" + "Bston"
city_weather = requests.get(city_url)
if city_weather.json():
    print(f"City Weather found.")
else:
    print(f"City weather not found.")
# Out:
# City Weather found.

# %%
print(city_url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=eb273abd97be6fe0052f516f1f4d8101&q=Bston

# %%
# Create an endpoint URL for a city.
city_url = url + "&q=" + "Boston"
city_weather = requests.get(city_url)
city_weather.json()
# Out:
# {'coord': {'lon': -71.06, 'lat': 42.36},
#  'weather': [{'id': 800,
#    'main': 'Clear',
#    'description': 'clear sky',
#    'icon': '01n'}],
#  'base': 'stations',
#  'main': {'temp': 40.06,
#   'feels_like': 32.07,
#   'temp_min': 33.01,
#   'temp_max': 46.4,
#   'pressure': 1010,
#   'humidity': 75},
#  'visibility': 16093,
#  'wind': {'speed': 8.05, 'deg': 220},
#  'clouds': {'all': 1},
#  'dt': 1578020163,
#  'sys': {'type': 1,
#   'id': 4210,
#   'country': 'US',
#   'sunrise': 1577967208,
#   'sunset': 1578000140},
#  'timezone': -18000,
#  'id': 4930956,
#  'name': 'Boston',
#  'cod': 200}

# %%
# Get the JSON data.
boston_data = city_weather.json()

# %%
boston_data['sys']
# Out:
# {'type': 1,
#  'id': 4210,
#  'country': 'US',
#  'sunrise': 1577967208,
#  'sunset': 1578000140}

# %%
boston_data["sys"]["country"]
# Out:
# 'US'

# %%
boston_data["dt"]
# Out:
# 1578020163

# %%
lat = boston_data["coord"]["lat"]
lng = boston_data["coord"]["lon"]
max_temp = boston_data["main"]["temp_max"]
humidity = boston_data["main"]["humidity"]
clouds = boston_data["clouds"]["all"]
wind = boston_data["wind"]["speed"]
print(lat, lng, max_temp, humidity, clouds, wind)
# Out:
# 42.36 -71.06 46.4 75 1 8.05

# %%
boston_data["dt"]
# Out:
# 1578020163

# %%
# Import the datetime module from the datetime library.
from datetime import datetime
# Get the date from the JSON file.
date = boston_data["dt"]
# Convert the UTC date to a date format with year, month, day, hours, minutes, and seconds.
datetime.utcfromtimestamp(date).strftime('%Y-%m-%d %H:%M:%S')
# Out:
# '2020-01-03 02:56:03'
